# %% [markdown]
# <a href="https://colab.research.google.com/github/smitaforward/Basics/blob/master/Altair_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://altair-viz.github.io/user_guide/data.html#

# %% [markdown]
# **Specifying Data in Altair**

# %%
import altair as alt
import pandas as pd

# %%
data = pd.DataFrame({'x':['A', 'B', 'C', 'D', 'E'], 
                    'y':[5, 3, 4, 6, 8]})
data
# Out:
#    x  y
# 0  A  5
# 1  B  3
# 2  C  4
# 3  D  6
# 4  E  8

# %%
alt.Chart(data).mark_bar().encode(
x = 'x',
y = 'y')
# Out:
# Chart({
#   data:    x  y
#   0  A  5
#   1  B  3
#   2  C  4
#   3  D  6
#   4  E  8,
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'x'
#     }),
#     y: Y({
#       shorthand: 'y'
#     })
#   }),
#   mark: 'bar'
# })

# %%
from vega_datasets import data
url = data.cars.url
url
# Out:
# 'https://vega.github.io/vega-datasets/data/cars.json'

# %%
alt.Chart(url).mark_point().encode(
x='Horsepower:Q',
y='Miles_per_Gallon:Q')
# Out:
# Chart({
#   data: 'https://vega.github.io/vega-datasets/data/cars.json',
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'Horsepower:Q'
#     }),
#     y: Y({
#       shorthand: 'Miles_per_Gallon:Q'
#     })
#   }),
#   mark: 'point'
# })

# %%
import numpy as np
rand = np.random.RandomState(0)

data = pd.DataFrame({'value':rand.randn(100).cumsum()}, 
                    index = pd.date_range('2018', freq='D', periods=100))
data.head()
# Out:
#                value
# 2018-01-01  1.764052
# 2018-01-02  2.164210
# 2018-01-03  3.142948
# 2018-01-04  5.383841
# 2018-01-05  7.251399

# %%
# include index data
alt.Chart(data.reset_index()).mark_line().encode(
x='index:T',
y='value:Q')
# Out:
# Chart({
#   data:         index      value
#   0  2018-01-01   1.764052
#   1  2018-01-02   2.164210
#   2  2018-01-03   3.142948
#   3  2018-01-04   5.383841
#   4  2018-01-05   7.251399
#   5  2018-01-06   6.274121
#   6  2018-01-07   7.224209
#   7  2018-01-08   7.072852
#   8  2018-01-09   6.969633
#   9  2018-01-10   7.380232
#   10 2018-01-11   7.524275
#   11 2018-01-12   8.978549
#   12 2018-01-13   9.739587
#   13 2018-01-14   9.861262
#   14 2018-01-15  10.305125
#   15 2018-01-16  10.638799
#   16 2018-01-17  12.132878
#   17 2018-01-18  11.927720
#   18 2018-01-19  12.240788
#   19 2018-01-20  11.386692
#   20 2018-01-21   8.833702
#   21 2018-01-22   9.487321
#   22 2018-01-23  10.351757
#   23 2018-01-24   9.609592
#   24 2018-01-25  11.879346
#   25 2018-01-26  10.424981
#   26 2018-01-27  10.470739
#   27 2018-01-28  10.283555
#   28 2018-01-29  11.816335
#   29 2018-01-30  13.285693
#   ..        ...        ...
#   70 2018-03-12  -0.489438
#   71 2018-03-13  -0.360455
#   72 2018-03-14   0.778946
#   73 2018-03-15  -0.455880
#   74 2018-03-16  -0.053539
#   75 2018-03-17  -0.738349
#   76 2018-03-18  -1.609146
#   77 2018-03-19  -2.187996
#   78 2018-03-20  -2.499548
#   79 2018-03-21  -2.443383
#   80 2018-03-22  -3.608533
#   81 2018-03-23  -2.707706
#   82 2018-03-24  -2.242044
#   83 2018-03-25  -3.778287
#   84 2018-03-26  -2.290035
#   85 2018-03-27  -0.394146
#   86 2018-03-28   0.784634
#   87 2018-03-29   0.604709
#   88 2018-03-30  -0.466044
#   89 2018-03-31   0.588408
#   90 2018-04-01   0.185231
#   91 2018-04-02   1.407676
#   92 2018-04-03   1.615951
#   93 2018-04-04   2.592590
#   94 2018-04-05   2.948956
#   95 2018-04-06   3.655530
#   96 2018-04-07   3.666030
#   97 2018-04-08   5.451900
#   98 2018-04-09   5.578812
#   99 2018-04-10   5.980802
#
#   [100 rows x 2 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'index:T'
#     }),
#     y: Y({
#       shorthand: 'value:Q'
#     })
#   }),
#   mark: 'line'
# })

# %%
#  Altair works best with this long-form data, because relevant data and metadata are stored within the table itself, 
# rather than within the labels of rows and columns

wide_form = pd.DataFrame({'Date': ['2007-10-01', '2007-11-01', '2007-12-01'],
                          'AAPL': [189.95, 182.22, 198.08],
                          'AMZN': [89.15, 90.56, 92.64],
                          'GOOG': [707.00, 693.00, 691.48]})
wide_form
# Out:
#          Date    AAPL   AMZN    GOOG
# 0  2007-10-01  189.95  89.15  707.00
# 1  2007-11-01  182.22  90.56  693.00
# 2  2007-12-01  198.08  92.64  691.48

# %%
long_form=wide_form.melt(id_vars = 'Date', var_name = 'company', value_name = 'price')
long_form
# Out:
#          Date company   price
# 0  2007-10-01    AAPL  189.95
# 1  2007-11-01    AAPL  182.22
# 2  2007-12-01    AAPL  198.08
# 3  2007-10-01    AMZN   89.15
# 4  2007-11-01    AMZN   90.56
# 5  2007-12-01    AMZN   92.64
# 6  2007-10-01    GOOG  707.00
# 7  2007-11-01    GOOG  693.00
# 8  2007-12-01    GOOG  691.48

# %%
alt.Chart(long_form).mark_line().encode(
x='Date:T',
y='price:Q',
color='company:N')
# Out:
# Chart({
#   data:          Date company   price
#   0  2007-10-01    AAPL  189.95
#   1  2007-11-01    AAPL  182.22
#   2  2007-12-01    AAPL  198.08
#   3  2007-10-01    AMZN   89.15
#   4  2007-11-01    AMZN   90.56
#   5  2007-12-01    AMZN   92.64
#   6  2007-10-01    GOOG  707.00
#   7  2007-11-01    GOOG  693.00
#   8  2007-12-01    GOOG  691.48,
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'company:N'
#     }),
#     x: X({
#       shorthand: 'Date:T'
#     }),
#     y: Y({
#       shorthand: 'price:Q'
#     })
#   }),
#   mark: 'line'
# })

# %% [markdown]
# https://altair-viz.github.io/user_guide/encoding.html

# %% [markdown]
# **Encoding**

# %%
from vega_datasets import data
cars=data.cars()
cars.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs       Year
# 0  chevrolet chevelle malibu    USA           3504 1970-01-01
# 1          buick skylark 320    USA           3693 1970-01-01
# 2         plymouth satellite    USA           3436 1970-01-01
# 3              amc rebel sst    USA           3433 1970-01-01
# 4                ford torino    USA           3449 1970-01-01

# %%
alt.Chart(cars).mark_point().encode(
x='Horsepower:Q',
y='Miles_per_Gallon:Q',
color='Origin:N',
shape='Origin:N')
# Out:
# Chart({
#   data:      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
#   0            12.0          8         307.0       130.0              18.0
#   1            11.5          8         350.0       165.0              15.0
#   2            11.0          8         318.0       150.0              18.0
#   3            12.0          8         304.0       150.0              16.0
#   4            10.5          8         302.0       140.0              17.0
#   5            10.0          8         429.0       198.0              15.0
#   6             9.0          8         454.0       220.0              14.0
#   7             8.5          8         440.0       215.0              14.0
#   8            10.0          8         455.0       225.0              14.0
#   9             8.5          8         390.0       190.0              15.0
#   10           17.5          4         133.0       115.0               NaN
#   11           11.5          8         350.0       165.0               NaN
#   12           11.0          8         351.0       153.0               NaN
#   13           10.5          8         383.0       175.0               NaN
#   14           11.0          8         360.0       175.0               NaN
#   15           10.0          8         383.0       170.0              15.0
#   16            8.0          8         340.0       160.0              14.0
#   17            8.0          8         302.0       140.0               NaN
#   18            9.5          8         400.0       150.0              15.0
#   19           10.0          8         455.0       225.0              14.0
#   20           15.0          4         113.0        95.0              24.0
#   21           15.5          6         198.0        95.0              22.0
#   22           15.5          6         199.0        97.0              18.0
#   23           16.0          6         200.0        85.0              21.0
#   24           14.5          4          97.0        88.0              27.0
#   25           20.5          4          97.0        46.0              26.0
#   26           17.5          4         110.0        87.0              25.0
#   27           14.5          4         107.0        90.0              24.0
#   28           17.5          4         104.0        95.0              25.0
#   29           12.5          4         121.0       113.0              26.0
#   ..            ...        ...           ...         ...               ...
#   376          18.6          4         112.0        88.0              27.0
#   377          18.0          4         112.0        88.0              34.0
#   378          16.2          4         112.0        85.0              31.0
#   379          16.0          4         135.0        84.0              29.0
#   380          18.0          4         151.0        90.0              27.0
#   381          16.4          4         140.0        92.0              24.0
#   382          20.5          4         151.0         NaN              23.0
#   383          15.3          4         105.0        74.0              36.0
#   384          18.2          4          91.0        68.0              37.0
#   385          17.6          4          91.0        68.0              31.0
#   386          14.7          4         105.0        63.0              38.0
#   387          17.3          4          98.0        70.0              36.0
#   388          14.5          4         120.0        88.0              36.0
#   389          14.5          4         107.0        75.0              36.0
#   390          16.9          4         108.0        70.0              34.0
#   391          15.0          4          91.0        67.0              38.0
#   392          15.7          4          91.0        67.0              32.0
#   393          16.2          4          91.0        67.0              38.0
#   394          16.4          6         181.0       110.0              25.0
#   395          17.0          6         262.0        85.0              38.0
#   396          14.5          4         156.0        92.0              26.0
#   397          14.7          6         232.0       112.0              22.0
#   398          13.9          4         144.0        96.0              32.0
#   399          13.0          4         135.0        84.0              36.0
#   400          17.3          4         151.0        90.0              27.0
#   401          15.6          4         140.0        86.0              27.0
#   402          24.6          4          97.0        52.0              44.0
#   403          11.6          4         135.0        84.0              32.0
#   404          18.6          4         120.0        79.0              28.0
#   405          19.4          4         119.0        82.0              31.0
#
#                                     Name  Origin  Weight_in_lbs       Year
#   0            chevrolet chevelle malibu     USA           3504 1970-01-01
#   1                    buick skylark 320     USA           3693 1970-01-01
#   2                   plymouth satellite     USA           3436 1970-01-01
#   3                        amc rebel sst     USA           3433 1970-01-01
#   4                          ford torino     USA           3449 1970-01-01
#   5                     ford galaxie 500     USA           4341 1970-01-01
#   6                     chevrolet impala     USA           4354 1970-01-01
#   7                    plymouth fury iii     USA           4312 1970-01-01
#   8                     pontiac catalina     USA           4425 1970-01-01
#   9                   amc ambassador dpl     USA           3850 1970-01-01
#   10                citroen ds-21 pallas  Europe           3090 1970-01-01
#   11    chevrolet chevelle concours (sw)     USA           4142 1970-01-01
#   12                    ford torino (sw)     USA           4034 1970-01-01
#   13             plymouth satellite (sw)     USA           4166 1970-01-01
#   14                  amc rebel sst (sw)     USA           3850 1970-01-01
#   15                 dodge challenger se     USA           3563 1970-01-01
#   16                  plymouth 'cuda 340     USA           3609 1970-01-01
#   17               ford mustang boss 302     USA           3353 1970-01-01
#   18               chevrolet monte carlo     USA           3761 1970-01-01
#   19             buick estate wagon (sw)     USA           3086 1970-01-01
#   20               toyota corona mark ii   Japan           2372 1970-01-01
#   21                     plymouth duster     USA           2833 1970-01-01
#   22                          amc hornet     USA           2774 1970-01-01
#   23                       ford maverick     USA           2587 1970-01-01
#   24                        datsun pl510   Japan           2130 1970-01-01
#   25        volkswagen 1131 deluxe sedan  Europe           1835 1970-01-01
#   26                         peugeot 504  Europe           2672 1970-01-01
#   27                         audi 100 ls  Europe           2430 1970-01-01
#   28                            saab 99e  Europe           2375 1970-01-01
#   29                            bmw 2002  Europe           2234 1970-01-01
#   ..                                 ...     ...            ...        ...
#   376           chevrolet cavalier wagon     USA           2640 1982-01-01
#   377          chevrolet cavalier 2-door     USA           2395 1982-01-01
#   378         pontiac j2000 se hatchback     USA           2575 1982-01-01
#   379                     dodge aries se     USA           2525 1982-01-01
#   380                    pontiac phoenix     USA           2735 1982-01-01
#   381               ford fairmont futura     USA           2865 1982-01-01
#   382                     amc concord dl     USA           3035 1982-01-01
#   383                volkswagen rabbit l  Europe           1980 1982-01-01
#   384                 mazda glc custom l   Japan           2025 1982-01-01
#   385                   mazda glc custom   Japan           1970 1982-01-01
#   386             plymouth horizon miser     USA           2125 1982-01-01
#   387                     mercury lynx l     USA           2125 1982-01-01
#   388                   nissan stanza xe   Japan           2160 1982-01-01
#   389              honda Accelerationord   Japan           2205 1982-01-01
#   390                     toyota corolla   Japan           2245 1982-01-01
#   391                        honda civic   Japan           1965 1982-01-01
#   392                 honda civic (auto)   Japan           1965 1982-01-01
#   393                      datsun 310 gx   Japan           1995 1982-01-01
#   394              buick century limited     USA           2945 1982-01-01
#   395  oldsmobile cutlass ciera (diesel)     USA           3015 1982-01-01
#   396         chrysler lebaron medallion     USA           2585 1982-01-01
#   397                     ford granada l     USA           2835 1982-01-01
#   398                   toyota celica gt   Japan           2665 1982-01-01
#   399                  dodge charger 2.2     USA           2370 1982-01-01
#   400                   chevrolet camaro     USA           2950 1982-01-01
#   401                    ford mustang gl     USA           2790 1982-01-01
#   402                          vw pickup  Europe           2130 1982-01-01
#   403                      dodge rampage     USA           2295 1982-01-01
#   404                        ford ranger     USA           2625 1982-01-01
#   405                         chevy s-10     USA           2720 1982-01-01
#
#   [406 rows x 9 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'Origin:N'
#     }),
#     shape: Shape({
#       shorthand: 'Origin:N'
#     }),
#     x: X({
#       shorthand: 'Horsepower:Q'
#     }),
#     y: Y({
#       shorthand: 'Miles_per_Gallon:Q'
#     })
#   }),
#   mark: 'point'
# })

# %%
base=alt.Chart(cars).mark_point().encode(
x='Horsepower:Q',
y='Miles_per_Gallon:Q').properties(width=150, height=150)

# %%
alt.vconcat(
base.encode(color='Cylinders:Q').properties(title='quantitative'),
base.encode(color='Cylinders:O').properties(title='ordinary'),
base.encode(color='Cylinders:N').properties(title='nominal'))
# Out:
# VConcatChart({
#   vconcat: [Chart({
#     data:      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
#     0            12.0          8         307.0       130.0              18.0
#     1            11.5          8         350.0       165.0              15.0
#     2            11.0          8         318.0       150.0              18.0
#     3            12.0          8         304.0       150.0              16.0
#     4            10.5          8         302.0       140.0              17.0
#     5            10.0          8         429.0       198.0              15.0
#     6             9.0          8         454.0       220.0              14.0
#     7             8.5          8         440.0       215.0              14.0
#     8            10.0          8         455.0       225.0              14.0
#     9             8.5          8         390.0       190.0              15.0
#     10           17.5          4         133.0       115.0               NaN
#     11           11.5          8         350.0       165.0               NaN
#     12           11.0          8         351.0       153.0               NaN
#     13           10.5          8         383.0       175.0               NaN
#     14           11.0          8         360.0       175.0               NaN
#     15           10.0          8         383.0       170.0              15.0
#     16            8.0          8         340.0       160.0              14.0
#     17            8.0          8         302.0       140.0               NaN
#     18            9.5          8         400.0       150.0              15.0
#     19           10.0          8         455.0       225.0              14.0
#     20           15.0          4         113.0        95.0              24.0
#     21           15.5          6         198.0        95.0              22.0
#     22           15.5          6         199.0        97.0              18.0
#     23           16.0          6         200.0        85.0              21.0
#     24           14.5          4          97.0        88.0              27.0
#     25           20.5          4          97.0        46.0              26.0
#     26           17.5          4         110.0        87.0              25.0
#     27           14.5          4         107.0        90.0              24.0
#     28           17.5          4         104.0        95.0              25.0
#     29           12.5          4         121.0       113.0              26.0
#     ..            ...        ...           ...         ...               ...
#     376          18.6          4         112.0        88.0              27.0
#     377          18.0          4         112.0        88.0              34.0
#     378          16.2          4         112.0        85.0              31.0
#     379          16.0          4         135.0        84.0              29.0
#     380          18.0          4         151.0        90.0              27.0
#     381          16.4          4         140.0        92.0              24.0
#     382          20.5          4         151.0         NaN              23.0
#     383          15.3          4         105.0        74.0              36.0
#     384          18.2          4          91.0        68.0              37.0
#     385          17.6          4          91.0        68.0              31.0
#     386          14.7          4         105.0        63.0              38.0
#     387          17.3          4          98.0        70.0              36.0
#     388          14.5          4         120.0        88.0              36.0
#     389          14.5          4         107.0        75.0              36.0
#     390          16.9          4         108.0        70.0              34.0
#     391          15.0          4          91.0        67.0              38.0
#     392          15.7          4          91.0        67.0              32.0
#     393          16.2          4          91.0        67.0              38.0
#     394          16.4          6         181.0       110.0              25.0
#     395          17.0          6         262.0        85.0              38.0
#     396          14.5          4         156.0        92.0              26.0
#     397          14.7          6         232.0       112.0              22.0
#     398          13.9          4         144.0        96.0              32.0
#     399          13.0          4         135.0        84.0              36.0
#     400          17.3          4         151.0        90.0              27.0
#     401          15.6          4         140.0        86.0              27.0
#     402          24.6          4          97.0        52.0              44.0
#     403          11.6          4         135.0        84.0              32.0
#     404          18.6          4         120.0        79.0              28.0
#     405          19.4          4         119.0        82.0              31.0
#
#                                       Name  Origin  Weight_in_lbs       Year
#     0            chevrolet chevelle malibu     USA           3504 1970-01-01
#     1                    buick skylark 320     USA           3693 1970-01-01
#     2                   plymouth satellite     USA           3436 1970-01-01
#     3                        amc rebel sst     USA           3433 1970-01-01
#     4                          ford torino     USA           3449 1970-01-01
#     5                     ford galaxie 500     USA           4341 1970-01-01
#     6                     chevrolet impala     USA           4354 1970-01-01
#     7                    plymouth fury iii     USA           4312 1970-01-01
#     8                     pontiac catalina     USA           4425 1970-01-01
#     9                   amc ambassador dpl     USA           3850 1970-01-01
#     10                citroen ds-21 pallas  Europe           3090 1970-01-01
#     11    chevrolet chevelle concours (sw)     USA           4142 1970-01-01
#     12                    ford torino (sw)     USA           4034 1970-01-01
#     13             plymouth satellite (sw)     USA           4166 1970-01-01
#     14                  amc rebel sst (sw)     USA           3850 1970-01-01
#     15                 dodge challenger se     USA           3563 1970-01-01
#     16                  plymouth 'cuda 340     USA           3609 1970-01-01
#     17               ford mustang boss 302     USA           3353 1970-01-01
#     18               chevrolet monte carlo     USA           3761 1970-01-01
#     19             buick estate wagon (sw)     USA           3086 1970-01-01
#     20               toyota corona mark ii   Japan           2372 1970-01-01
#     21                     plymouth duster     USA           2833 1970-01-01
#     22                          amc hornet     USA           2774 1970-01-01
#     23                       ford maverick     USA           2587 1970-01-01
#     24                        datsun pl510   Japan           2130 1970-01-01
#     25        volkswagen 1131 deluxe sedan  Europe           1835 1970-01-01
#     26                         peugeot 504  Europe           2672 1970-01-01
#     27                         audi 100 ls  Europe           2430 1970-01-01
#     28                            saab 99e  Europe           2375 1970-01-01
#     29                            bmw 2002  Europe           2234 1970-01-01
#     ..                                 ...     ...            ...        ...
#     376           chevrolet cavalier wagon     USA           2640 1982-01-01
#     377          chevrolet cavalier 2-door     USA           2395 1982-01-01
#     378         pontiac j2000 se hatchback     USA           2575 1982-01-01
#     379                     dodge aries se     USA           2525 1982-01-01
#     380                    pontiac phoenix     USA           2735 1982-01-01
#     381               ford fairmont futura     USA           2865 1982-01-01
#     382                     amc concord dl     USA           3035 1982-01-01
#     383                volkswagen rabbit l  Europe           1980 1982-01-01
#     384                 mazda glc custom l   Japan           2025 1982-01-01
#     385                   mazda glc custom   Japan           1970 1982-01-01
#     386             plymouth horizon miser     USA           2125 1982-01-01
#     387                     mercury lynx l     USA           2125 1982-01-01
#     388                   nissan stanza xe   Japan           2160 1982-01-01
#     389              honda Accelerationord   Japan           2205 1982-01-01
#     390                     toyota corolla   Japan           2245 1982-01-01
#     391                        honda civic   Japan           1965 1982-01-01
#     392                 honda civic (auto)   Japan           1965 1982-01-01
#     393                      datsun 310 gx   Japan           1995 1982-01-01
#     394              buick century limited     USA           2945 1982-01-01
#     395  oldsmobile cutlass ciera (diesel)     USA           3015 1982-01-01
#     396         chrysler lebaron medallion     USA           2585 1982-01-01
#     397                     ford granada l     USA           2835 1982-01-01
#     398                   toyota celica gt   Japan           2665 1982-01-01
#     399                  dodge charger 2.2     USA           2370 1982-01-01
#     400                   chevrolet camaro     USA           2950 1982-01-01
#     401                    ford mustang gl     USA           2790 1982-01-01
#     402                          vw pickup  Europe           2130 1982-01-01
#     403                      dodge rampage     USA           2295 1982-01-01
#     404                        ford ranger     USA           2625 1982-01-01
#     405                         chevy s-10     USA           2720 1982-01-01
#
#     [406 rows x 9 columns],
#     encoding: EncodingWithFacet({
#       color: Color({
#         shorthand: 'Cylinders:Q'
#       }),
#       x: X({
#         shorthand: 'Horsepower:Q'
#       }),
#       y: Y({
#         shorthand: 'Miles_per_Gallon:Q'
#       })
#     }),
#     height: 150,
#     mark: 'point',
#     title: 'quantitative',
#     width: 150
#   }), Chart({
#     data:      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
#     0            12.0          8         307.0       130.0              18.0
#     1            11.5          8         350.0       165.0              15.0
#     2            11.0          8         318.0       150.0              18.0
#     3            12.0          8         304.0       150.0              16.0
#     4            10.5          8         302.0       140.0              17.0
#     5            10.0          8         429.0       198.0              15.0
#     6             9.0          8         454.0       220.0              14.0
#     7             8.5          8         440.0       215.0              14.0
#     8            10.0          8         455.0       225.0              14.0
#     9             8.5          8         390.0       190.0              15.0
#     10           17.5          4         133.0       115.0               NaN
#     11           11.5          8         350.0       165.0               NaN
#     12           11.0          8         351.0       153.0               NaN
#     13           10.5          8         383.0       175.0               NaN
#     14           11.0          8         360.0       175.0               NaN
#     15           10.0          8         383.0       170.0              15.0
#     16            8.0          8         340.0       160.0              14.0
#     17            8.0          8         302.0       140.0               NaN
#     18            9.5          8         400.0       150.0              15.0
#     19           10.0          8         455.0       225.0              14.0
#     20           15.0          4         113.0        95.0              24.0
#     21           15.5          6         198.0        95.0              22.0
#     22           15.5          6         199.0        97.0              18.0
#     23           16.0          6         200.0        85.0              21.0
#     24           14.5          4          97.0        88.0              27.0
#     25           20.5          4          97.0        46.0              26.0
#     26           17.5          4         110.0        87.0              25.0
#     27           14.5          4         107.0        90.0              24.0
#     28           17.5          4         104.0        95.0              25.0
#     29           12.5          4         121.0       113.0              26.0
#     ..            ...        ...           ...         ...               ...
#     376          18.6          4         112.0        88.0              27.0
#     377          18.0          4         112.0        88.0              34.0
#     378          16.2          4         112.0        85.0              31.0
#     379          16.0          4         135.0        84.0              29.0
#     380          18.0          4         151.0        90.0              27.0
#     381          16.4          4         140.0        92.0              24.0
#     382          20.5          4         151.0         NaN              23.0
#     383          15.3          4         105.0        74.0              36.0
#     384          18.2          4          91.0        68.0              37.0
#     385          17.6          4          91.0        68.0              31.0
#     386          14.7          4         105.0        63.0              38.0
#     387          17.3          4          98.0        70.0              36.0
#     388          14.5          4         120.0        88.0              36.0
#     389          14.5          4         107.0        75.0              36.0
#     390          16.9          4         108.0        70.0              34.0
#     391          15.0          4          91.0        67.0              38.0
#     392          15.7          4          91.0        67.0              32.0
#     393          16.2          4          91.0        67.0              38.0
#     394          16.4          6         181.0       110.0              25.0
#     395          17.0          6         262.0        85.0              38.0
#     396          14.5          4         156.0        92.0              26.0
#     397          14.7          6         232.0       112.0              22.0
#     398          13.9          4         144.0        96.0              32.0
#     399          13.0          4         135.0        84.0              36.0
#     400          17.3          4         151.0        90.0              27.0
#     401          15.6          4         140.0        86.0              27.0
#     402          24.6          4          97.0        52.0              44.0
#     403          11.6          4         135.0        84.0              32.0
#     404          18.6          4         120.0        79.0              28.0
#     405          19.4          4         119.0        82.0              31.0
#
#                                       Name  Origin  Weight_in_lbs       Year
#     0            chevrolet chevelle malibu     USA           3504 1970-01-01
#     1                    buick skylark 320     USA           3693 1970-01-01
#     2                   plymouth satellite     USA           3436 1970-01-01
#     3                        amc rebel sst     USA           3433 1970-01-01
#     4                          ford torino     USA           3449 1970-01-01
#     5                     ford galaxie 500     USA           4341 1970-01-01
#     6                     chevrolet impala     USA           4354 1970-01-01
#     7                    plymouth fury iii     USA           4312 1970-01-01
#     8                     pontiac catalina     USA           4425 1970-01-01
#     9                   amc ambassador dpl     USA           3850 1970-01-01
#     10                citroen ds-21 pallas  Europe           3090 1970-01-01
#     11    chevrolet chevelle concours (sw)     USA           4142 1970-01-01
#     12                    ford torino (sw)     USA           4034 1970-01-01
#     13             plymouth satellite (sw)     USA           4166 1970-01-01
#     14                  amc rebel sst (sw)     USA           3850 1970-01-01
#     15                 dodge challenger se     USA           3563 1970-01-01
#     16                  plymouth 'cuda 340     USA           3609 1970-01-01
#     17               ford mustang boss 302     USA           3353 1970-01-01
#     18               chevrolet monte carlo     USA           3761 1970-01-01
#     19             buick estate wagon (sw)     USA           3086 1970-01-01
#     20               toyota corona mark ii   Japan           2372 1970-01-01
#     21                     plymouth duster     USA           2833 1970-01-01
#     22                          amc hornet     USA           2774 1970-01-01
#     23                       ford maverick     USA           2587 1970-01-01
#     24                        datsun pl510   Japan           2130 1970-01-01
#     25        volkswagen 1131 deluxe sedan  Europe           1835 1970-01-01
#     26                         peugeot 504  Europe           2672 1970-01-01
#     27                         audi 100 ls  Europe           2430 1970-01-01
#     28                            saab 99e  Europe           2375 1970-01-01
#     29                            bmw 2002  Europe           2234 1970-01-01
#     ..                                 ...     ...            ...        ...
#     376           chevrolet cavalier wagon     USA           2640 1982-01-01
#     377          chevrolet cavalier 2-door     USA           2395 1982-01-01
#     378         pontiac j2000 se hatchback     USA           2575 1982-01-01
#     379                     dodge aries se     USA           2525 1982-01-01
#     380                    pontiac phoenix     USA           2735 1982-01-01
#     381               ford fairmont futura     USA           2865 1982-01-01
#     382                     amc concord dl     USA           3035 1982-01-01
#     383                volkswagen rabbit l  Europe           1980 1982-01-01
#     384                 mazda glc custom l   Japan           2025 1982-01-01
#     385                   mazda glc custom   Japan           1970 1982-01-01
#     386             plymouth horizon miser     USA           2125 1982-01-01
#     387                     mercury lynx l     USA           2125 1982-01-01
#     388                   nissan stanza xe   Japan           2160 1982-01-01
#     389              honda Accelerationord   Japan           2205 1982-01-01
#     390                     toyota corolla   Japan           2245 1982-01-01
#     391                        honda civic   Japan           1965 1982-01-01
#     392                 honda civic (auto)   Japan           1965 1982-01-01
#     393                      datsun 310 gx   Japan           1995 1982-01-01
#     394              buick century limited     USA           2945 1982-01-01
#     395  oldsmobile cutlass ciera (diesel)     USA           3015 1982-01-01
#     396         chrysler lebaron medallion     USA           2585 1982-01-01
#     397                     ford granada l     USA           2835 1982-01-01
#     398                   toyota celica gt   Japan           2665 1982-01-01
#     399                  dodge charger 2.2     USA           2370 1982-01-01
#     400                   chevrolet camaro     USA           2950 1982-01-01
#     401                    ford mustang gl     USA           2790 1982-01-01
#     402                          vw pickup  Europe           2130 1982-01-01
#     403                      dodge rampage     USA           2295 1982-01-01
#     404                        ford ranger     USA           2625 1982-01-01
#     405                         chevy s-10     USA           2720 1982-01-01
#
#     [406 rows x 9 columns],
#     encoding: EncodingWithFacet({
#       color: Color({
#         shorthand: 'Cylinders:O'
#       }),
#       x: X({
#         shorthand: 'Horsepower:Q'
#       }),
#       y: Y({
#         shorthand: 'Miles_per_Gallon:Q'
#       })
#     }),
#     height: 150,
#     mark: 'point',
#     title: 'ordinary',
#     width: 150
#   }), Chart({
#     data:      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
#     0            12.0          8         307.0       130.0              18.0
#     1            11.5          8         350.0       165.0              15.0
#     2            11.0          8         318.0       150.0              18.0
#     3            12.0          8         304.0       150.0              16.0
#     4            10.5          8         302.0       140.0              17.0
#     5            10.0          8         429.0       198.0              15.0
#     6             9.0          8         454.0       220.0              14.0
#     7             8.5          8         440.0       215.0              14.0
#     8            10.0          8         455.0       225.0              14.0
#     9             8.5          8         390.0       190.0              15.0
#     10           17.5          4         133.0       115.0               NaN
#     11           11.5          8         350.0       165.0               NaN
#     12           11.0          8         351.0       153.0               NaN
#     13           10.5          8         383.0       175.0               NaN
#     14           11.0          8         360.0       175.0               NaN
#     15           10.0          8         383.0       170.0              15.0
#     16            8.0          8         340.0       160.0              14.0
#     17            8.0          8         302.0       140.0               NaN
#     18            9.5          8         400.0       150.0              15.0
#     19           10.0          8         455.0       225.0              14.0
#     20           15.0          4         113.0        95.0              24.0
#     21           15.5          6         198.0        95.0              22.0
#     22           15.5          6         199.0        97.0              18.0
#     23           16.0          6         200.0        85.0              21.0
#     24           14.5          4          97.0        88.0              27.0
#     25           20.5          4          97.0        46.0              26.0
#     26           17.5          4         110.0        87.0              25.0
#     27           14.5          4         107.0        90.0              24.0
#     28           17.5          4         104.0        95.0              25.0
#     29           12.5          4         121.0       113.0              26.0
#     ..            ...        ...           ...         ...               ...
#     376          18.6          4         112.0        88.0              27.0
#     377          18.0          4         112.0        88.0              34.0
#     378          16.2          4         112.0        85.0              31.0
#     379          16.0          4         135.0        84.0              29.0
#     380          18.0          4         151.0        90.0              27.0
#     381          16.4          4         140.0        92.0              24.0
#     382          20.5          4         151.0         NaN              23.0
#     383          15.3          4         105.0        74.0              36.0
#     384          18.2          4          91.0        68.0              37.0
#     385          17.6          4          91.0        68.0              31.0
#     386          14.7          4         105.0        63.0              38.0
#     387          17.3          4          98.0        70.0              36.0
#     388          14.5          4         120.0        88.0              36.0
#     389          14.5          4         107.0        75.0              36.0
#     390          16.9          4         108.0        70.0              34.0
#     391          15.0          4          91.0        67.0              38.0
#     392          15.7          4          91.0        67.0              32.0
#     393          16.2          4          91.0        67.0              38.0
#     394          16.4          6         181.0       110.0              25.0
#     395          17.0          6         262.0        85.0              38.0
#     396          14.5          4         156.0        92.0              26.0
#     397          14.7          6         232.0       112.0              22.0
#     398          13.9          4         144.0        96.0              32.0
#     399          13.0          4         135.0        84.0              36.0
#     400          17.3          4         151.0        90.0              27.0
#     401          15.6          4         140.0        86.0              27.0
#     402          24.6          4          97.0        52.0              44.0
#     403          11.6          4         135.0        84.0              32.0
#     404          18.6          4         120.0        79.0              28.0
#     405          19.4          4         119.0        82.0              31.0
#
#                                       Name  Origin  Weight_in_lbs       Year
#     0            chevrolet chevelle malibu     USA           3504 1970-01-01
#     1                    buick skylark 320     USA           3693 1970-01-01
#     2                   plymouth satellite     USA           3436 1970-01-01
#     3                        amc rebel sst     USA           3433 1970-01-01
#     4                          ford torino     USA           3449 1970-01-01
#     5                     ford galaxie 500     USA           4341 1970-01-01
#     6                     chevrolet impala     USA           4354 1970-01-01
#     7                    plymouth fury iii     USA           4312 1970-01-01
#     8                     pontiac catalina     USA           4425 1970-01-01
#     9                   amc ambassador dpl     USA           3850 1970-01-01
#     10                citroen ds-21 pallas  Europe           3090 1970-01-01
#     11    chevrolet chevelle concours (sw)     USA           4142 1970-01-01
#     12                    ford torino (sw)     USA           4034 1970-01-01
#     13             plymouth satellite (sw)     USA           4166 1970-01-01
#     14                  amc rebel sst (sw)     USA           3850 1970-01-01
#     15                 dodge challenger se     USA           3563 1970-01-01
#     16                  plymouth 'cuda 340     USA           3609 1970-01-01
#     17               ford mustang boss 302     USA           3353 1970-01-01
#     18               chevrolet monte carlo     USA           3761 1970-01-01
#     19             buick estate wagon (sw)     USA           3086 1970-01-01
#     20               toyota corona mark ii   Japan           2372 1970-01-01
#     21                     plymouth duster     USA           2833 1970-01-01
#     22                          amc hornet     USA           2774 1970-01-01
#     23                       ford maverick     USA           2587 1970-01-01
#     24                        datsun pl510   Japan           2130 1970-01-01
#     25        volkswagen 1131 deluxe sedan  Europe           1835 1970-01-01
#     26                         peugeot 504  Europe           2672 1970-01-01
#     27                         audi 100 ls  Europe           2430 1970-01-01
#     28                            saab 99e  Europe           2375 1970-01-01
#     29                            bmw 2002  Europe           2234 1970-01-01
#     ..                                 ...     ...            ...        ...
#     376           chevrolet cavalier wagon     USA           2640 1982-01-01
#     377          chevrolet cavalier 2-door     USA           2395 1982-01-01
#     378         pontiac j2000 se hatchback     USA           2575 1982-01-01
#     379                     dodge aries se     USA           2525 1982-01-01
#     380                    pontiac phoenix     USA           2735 1982-01-01
#     381               ford fairmont futura     USA           2865 1982-01-01
#     382                     amc concord dl     USA           3035 1982-01-01
#     383                volkswagen rabbit l  Europe           1980 1982-01-01
#     384                 mazda glc custom l   Japan           2025 1982-01-01
#     385                   mazda glc custom   Japan           1970 1982-01-01
#     386             plymouth horizon miser     USA           2125 1982-01-01
#     387                     mercury lynx l     USA           2125 1982-01-01
#     388                   nissan stanza xe   Japan           2160 1982-01-01
#     389              honda Accelerationord   Japan           2205 1982-01-01
#     390                     toyota corolla   Japan           2245 1982-01-01
#     391                        honda civic   Japan           1965 1982-01-01
#     392                 honda civic (auto)   Japan           1965 1982-01-01
#     393                      datsun 310 gx   Japan           1995 1982-01-01
#     394              buick century limited     USA           2945 1982-01-01
#     395  oldsmobile cutlass ciera (diesel)     USA           3015 1982-01-01
#     396         chrysler lebaron medallion     USA           2585 1982-01-01
#     397                     ford granada l     USA           2835 1982-01-01
#     398                   toyota celica gt   Japan           2665 1982-01-01
#     399                  dodge charger 2.2     USA           2370 1982-01-01
#     400                   chevrolet camaro     USA           2950 1982-01-01
#     401                    ford mustang gl     USA           2790 1982-01-01
#     402                          vw pickup  Europe           2130 1982-01-01
#     403                      dodge rampage     USA           2295 1982-01-01
#     404                        ford ranger     USA           2625 1982-01-01
#     405                         chevy s-10     USA           2720 1982-01-01
#
#     [406 rows x 9 columns],
#     encoding: EncodingWithFacet({
#       color: Color({
#         shorthand: 'Cylinders:N'
#       }),
#       x: X({
#         shorthand: 'Horsepower:Q'
#       }),
#       y: Y({
#         shorthand: 'Miles_per_Gallon:Q'
#       })
#     }),
#     height: 150,
#     mark: 'point',
#     title: 'nominal',
#     width: 150
#   })]
# })

# %%
pop=data.population.url

base=alt.Chart(pop).mark_bar().encode(
alt.Y('mean(people):Q', axis=alt.Axis(title='total population'))
).properties(width=200, height=200)

# %%
alt.hconcat(
base.encode(x='year:Q').properties(title='year=quantitative'),#qantitative scale always starts from zero
base.encode(alt.X('year:Q', scale=alt.Scale(zero=False))).properties(title='year=quantitative 2'),
base.encode(x='year:O').properties(title='year=ordinal'))
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data: 'https://vega.github.io/vega-datasets/data/population.json',
#     encoding: EncodingWithFacet({
#       x: X({
#         shorthand: 'year:Q'
#       }),
#       y: Y({
#         axis: Axis({
#           title: 'total population'
#         }),
#         shorthand: 'mean(people):Q'
#       })
#     }),
#     height: 200,
#     mark: 'bar',
#     title: 'year=quantitative',
#     width: 200
#   }), Chart({
#     data: 'https://vega.github.io/vega-datasets/data/population.json',
#     encoding: EncodingWithFacet({
#       x: X({
#         scale: Scale({
#           zero: False
#         }),
#         shorthand: 'year:Q'
#       }),
#       y: Y({
#         axis: Axis({
#           title: 'total population'
#         }),
#         shorthand: 'mean(people):Q'
#       })
#     }),
#     height: 200,
#     mark: 'bar',
#     title: 'year=quantitative 2',
#     width: 200
#   }), Chart({
#     data: 'https://vega.github.io/vega-datasets/data/population.json',
#     encoding: EncodingWithFacet({
#       x: X({
#         shorthand: 'year:O'
#       }),
#       y: Y({
#         axis: Axis({
#           title: 'total population'
#         }),
#         shorthand: 'mean(people):Q'
#       })
#     }),
#     height: 200,
#     mark: 'bar',
#     title: 'year=ordinal',
#     width: 200
#   })]
# })

# %%
alt.Chart(cars).mark_bar().encode(
alt.X('Horsepower', bin=True, title='Horsepower'),
y='count()')
# Out:
# Chart({
#   data:      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
#   0            12.0          8         307.0       130.0              18.0
#   1            11.5          8         350.0       165.0              15.0
#   2            11.0          8         318.0       150.0              18.0
#   3            12.0          8         304.0       150.0              16.0
#   4            10.5          8         302.0       140.0              17.0
#   5            10.0          8         429.0       198.0              15.0
#   6             9.0          8         454.0       220.0              14.0
#   7             8.5          8         440.0       215.0              14.0
#   8            10.0          8         455.0       225.0              14.0
#   9             8.5          8         390.0       190.0              15.0
#   10           17.5          4         133.0       115.0               NaN
#   11           11.5          8         350.0       165.0               NaN
#   12           11.0          8         351.0       153.0               NaN
#   13           10.5          8         383.0       175.0               NaN
#   14           11.0          8         360.0       175.0               NaN
#   15           10.0          8         383.0       170.0              15.0
#   16            8.0          8         340.0       160.0              14.0
#   17            8.0          8         302.0       140.0               NaN
#   18            9.5          8         400.0       150.0              15.0
#   19           10.0          8         455.0       225.0              14.0
#   20           15.0          4         113.0        95.0              24.0
#   21           15.5          6         198.0        95.0              22.0
#   22           15.5          6         199.0        97.0              18.0
#   23           16.0          6         200.0        85.0              21.0
#   24           14.5          4          97.0        88.0              27.0
#   25           20.5          4          97.0        46.0              26.0
#   26           17.5          4         110.0        87.0              25.0
#   27           14.5          4         107.0        90.0              24.0
#   28           17.5          4         104.0        95.0              25.0
#   29           12.5          4         121.0       113.0              26.0
#   ..            ...        ...           ...         ...               ...
#   376          18.6          4         112.0        88.0              27.0
#   377          18.0          4         112.0        88.0              34.0
#   378          16.2          4         112.0        85.0              31.0
#   379          16.0          4         135.0        84.0              29.0
#   380          18.0          4         151.0        90.0              27.0
#   381          16.4          4         140.0        92.0              24.0
#   382          20.5          4         151.0         NaN              23.0
#   383          15.3          4         105.0        74.0              36.0
#   384          18.2          4          91.0        68.0              37.0
#   385          17.6          4          91.0        68.0              31.0
#   386          14.7          4         105.0        63.0              38.0
#   387          17.3          4          98.0        70.0              36.0
#   388          14.5          4         120.0        88.0              36.0
#   389          14.5          4         107.0        75.0              36.0
#   390          16.9          4         108.0        70.0              34.0
#   391          15.0          4          91.0        67.0              38.0
#   392          15.7          4          91.0        67.0              32.0
#   393          16.2          4          91.0        67.0              38.0
#   394          16.4          6         181.0       110.0              25.0
#   395          17.0          6         262.0        85.0              38.0
#   396          14.5          4         156.0        92.0              26.0
#   397          14.7          6         232.0       112.0              22.0
#   398          13.9          4         144.0        96.0              32.0
#   399          13.0          4         135.0        84.0              36.0
#   400          17.3          4         151.0        90.0              27.0
#   401          15.6          4         140.0        86.0              27.0
#   402          24.6          4          97.0        52.0              44.0
#   403          11.6          4         135.0        84.0              32.0
#   404          18.6          4         120.0        79.0              28.0
#   405          19.4          4         119.0        82.0              31.0
#
#                                     Name  Origin  Weight_in_lbs       Year
#   0            chevrolet chevelle malibu     USA           3504 1970-01-01
#   1                    buick skylark 320     USA           3693 1970-01-01
#   2                   plymouth satellite     USA           3436 1970-01-01
#   3                        amc rebel sst     USA           3433 1970-01-01
#   4                          ford torino     USA           3449 1970-01-01
#   5                     ford galaxie 500     USA           4341 1970-01-01
#   6                     chevrolet impala     USA           4354 1970-01-01
#   7                    plymouth fury iii     USA           4312 1970-01-01
#   8                     pontiac catalina     USA           4425 1970-01-01
#   9                   amc ambassador dpl     USA           3850 1970-01-01
#   10                citroen ds-21 pallas  Europe           3090 1970-01-01
#   11    chevrolet chevelle concours (sw)     USA           4142 1970-01-01
#   12                    ford torino (sw)     USA           4034 1970-01-01
#   13             plymouth satellite (sw)     USA           4166 1970-01-01
#   14                  amc rebel sst (sw)     USA           3850 1970-01-01
#   15                 dodge challenger se     USA           3563 1970-01-01
#   16                  plymouth 'cuda 340     USA           3609 1970-01-01
#   17               ford mustang boss 302     USA           3353 1970-01-01
#   18               chevrolet monte carlo     USA           3761 1970-01-01
#   19             buick estate wagon (sw)     USA           3086 1970-01-01
#   20               toyota corona mark ii   Japan           2372 1970-01-01
#   21                     plymouth duster     USA           2833 1970-01-01
#   22                          amc hornet     USA           2774 1970-01-01
#   23                       ford maverick     USA           2587 1970-01-01
#   24                        datsun pl510   Japan           2130 1970-01-01
#   25        volkswagen 1131 deluxe sedan  Europe           1835 1970-01-01
#   26                         peugeot 504  Europe           2672 1970-01-01
#   27                         audi 100 ls  Europe           2430 1970-01-01
#   28                            saab 99e  Europe           2375 1970-01-01
#   29                            bmw 2002  Europe           2234 1970-01-01
#   ..                                 ...     ...            ...        ...
#   376           chevrolet cavalier wagon     USA           2640 1982-01-01
#   377          chevrolet cavalier 2-door     USA           2395 1982-01-01
#   378         pontiac j2000 se hatchback     USA           2575 1982-01-01
#   379                     dodge aries se     USA           2525 1982-01-01
#   380                    pontiac phoenix     USA           2735 1982-01-01
#   381               ford fairmont futura     USA           2865 1982-01-01
#   382                     amc concord dl     USA           3035 1982-01-01
#   383                volkswagen rabbit l  Europe           1980 1982-01-01
#   384                 mazda glc custom l   Japan           2025 1982-01-01
#   385                   mazda glc custom   Japan           1970 1982-01-01
#   386             plymouth horizon miser     USA           2125 1982-01-01
#   387                     mercury lynx l     USA           2125 1982-01-01
#   388                   nissan stanza xe   Japan           2160 1982-01-01
#   389              honda Accelerationord   Japan           2205 1982-01-01
#   390                     toyota corolla   Japan           2245 1982-01-01
#   391                        honda civic   Japan           1965 1982-01-01
#   392                 honda civic (auto)   Japan           1965 1982-01-01
#   393                      datsun 310 gx   Japan           1995 1982-01-01
#   394              buick century limited     USA           2945 1982-01-01
#   395  oldsmobile cutlass ciera (diesel)     USA           3015 1982-01-01
#   396         chrysler lebaron medallion     USA           2585 1982-01-01
#   397                     ford granada l     USA           2835 1982-01-01
#   398                   toyota celica gt   Japan           2665 1982-01-01
#   399                  dodge charger 2.2     USA           2370 1982-01-01
#   400                   chevrolet camaro     USA           2950 1982-01-01
#   401                    ford mustang gl     USA           2790 1982-01-01
#   402                          vw pickup  Europe           2130 1982-01-01
#   403                      dodge rampage     USA           2295 1982-01-01
#   404                        ford ranger     USA           2625 1982-01-01
#   405                         chevy s-10     USA           2720 1982-01-01
#
#   [406 rows x 9 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       bin: True,
#       shorthand: 'Horsepower',
#       title: 'Horsepower'
#     }),
#     y: Y({
#       shorthand: 'count()'
#     })
#   }),
#   mark: 'bar'
# })

# %%
alt.Chart(cars).mark_point().encode(
alt.X('Horsepower', bin=True, title='Horsepower'),
alt.Y('Miles_per_Gallon', bin=True),
size='count()',
color='average(Acceleration):Q')
# Out:
# Chart({
#   data:      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
#   0            12.0          8         307.0       130.0              18.0
#   1            11.5          8         350.0       165.0              15.0
#   2            11.0          8         318.0       150.0              18.0
#   3            12.0          8         304.0       150.0              16.0
#   4            10.5          8         302.0       140.0              17.0
#   5            10.0          8         429.0       198.0              15.0
#   6             9.0          8         454.0       220.0              14.0
#   7             8.5          8         440.0       215.0              14.0
#   8            10.0          8         455.0       225.0              14.0
#   9             8.5          8         390.0       190.0              15.0
#   10           17.5          4         133.0       115.0               NaN
#   11           11.5          8         350.0       165.0               NaN
#   12           11.0          8         351.0       153.0               NaN
#   13           10.5          8         383.0       175.0               NaN
#   14           11.0          8         360.0       175.0               NaN
#   15           10.0          8         383.0       170.0              15.0
#   16            8.0          8         340.0       160.0              14.0
#   17            8.0          8         302.0       140.0               NaN
#   18            9.5          8         400.0       150.0              15.0
#   19           10.0          8         455.0       225.0              14.0
#   20           15.0          4         113.0        95.0              24.0
#   21           15.5          6         198.0        95.0              22.0
#   22           15.5          6         199.0        97.0              18.0
#   23           16.0          6         200.0        85.0              21.0
#   24           14.5          4          97.0        88.0              27.0
#   25           20.5          4          97.0        46.0              26.0
#   26           17.5          4         110.0        87.0              25.0
#   27           14.5          4         107.0        90.0              24.0
#   28           17.5          4         104.0        95.0              25.0
#   29           12.5          4         121.0       113.0              26.0
#   ..            ...        ...           ...         ...               ...
#   376          18.6          4         112.0        88.0              27.0
#   377          18.0          4         112.0        88.0              34.0
#   378          16.2          4         112.0        85.0              31.0
#   379          16.0          4         135.0        84.0              29.0
#   380          18.0          4         151.0        90.0              27.0
#   381          16.4          4         140.0        92.0              24.0
#   382          20.5          4         151.0         NaN              23.0
#   383          15.3          4         105.0        74.0              36.0
#   384          18.2          4          91.0        68.0              37.0
#   385          17.6          4          91.0        68.0              31.0
#   386          14.7          4         105.0        63.0              38.0
#   387          17.3          4          98.0        70.0              36.0
#   388          14.5          4         120.0        88.0              36.0
#   389          14.5          4         107.0        75.0              36.0
#   390          16.9          4         108.0        70.0              34.0
#   391          15.0          4          91.0        67.0              38.0
#   392          15.7          4          91.0        67.0              32.0
#   393          16.2          4          91.0        67.0              38.0
#   394          16.4          6         181.0       110.0              25.0
#   395          17.0          6         262.0        85.0              38.0
#   396          14.5          4         156.0        92.0              26.0
#   397          14.7          6         232.0       112.0              22.0
#   398          13.9          4         144.0        96.0              32.0
#   399          13.0          4         135.0        84.0              36.0
#   400          17.3          4         151.0        90.0              27.0
#   401          15.6          4         140.0        86.0              27.0
#   402          24.6          4          97.0        52.0              44.0
#   403          11.6          4         135.0        84.0              32.0
#   404          18.6          4         120.0        79.0              28.0
#   405          19.4          4         119.0        82.0              31.0
#
#                                     Name  Origin  Weight_in_lbs       Year
#   0            chevrolet chevelle malibu     USA           3504 1970-01-01
#   1                    buick skylark 320     USA           3693 1970-01-01
#   2                   plymouth satellite     USA           3436 1970-01-01
#   3                        amc rebel sst     USA           3433 1970-01-01
#   4                          ford torino     USA           3449 1970-01-01
#   5                     ford galaxie 500     USA           4341 1970-01-01
#   6                     chevrolet impala     USA           4354 1970-01-01
#   7                    plymouth fury iii     USA           4312 1970-01-01
#   8                     pontiac catalina     USA           4425 1970-01-01
#   9                   amc ambassador dpl     USA           3850 1970-01-01
#   10                citroen ds-21 pallas  Europe           3090 1970-01-01
#   11    chevrolet chevelle concours (sw)     USA           4142 1970-01-01
#   12                    ford torino (sw)     USA           4034 1970-01-01
#   13             plymouth satellite (sw)     USA           4166 1970-01-01
#   14                  amc rebel sst (sw)     USA           3850 1970-01-01
#   15                 dodge challenger se     USA           3563 1970-01-01
#   16                  plymouth 'cuda 340     USA           3609 1970-01-01
#   17               ford mustang boss 302     USA           3353 1970-01-01
#   18               chevrolet monte carlo     USA           3761 1970-01-01
#   19             buick estate wagon (sw)     USA           3086 1970-01-01
#   20               toyota corona mark ii   Japan           2372 1970-01-01
#   21                     plymouth duster     USA           2833 1970-01-01
#   22                          amc hornet     USA           2774 1970-01-01
#   23                       ford maverick     USA           2587 1970-01-01
#   24                        datsun pl510   Japan           2130 1970-01-01
#   25        volkswagen 1131 deluxe sedan  Europe           1835 1970-01-01
#   26                         peugeot 504  Europe           2672 1970-01-01
#   27                         audi 100 ls  Europe           2430 1970-01-01
#   28                            saab 99e  Europe           2375 1970-01-01
#   29                            bmw 2002  Europe           2234 1970-01-01
#   ..                                 ...     ...            ...        ...
#   376           chevrolet cavalier wagon     USA           2640 1982-01-01
#   377          chevrolet cavalier 2-door     USA           2395 1982-01-01
#   378         pontiac j2000 se hatchback     USA           2575 1982-01-01
#   379                     dodge aries se     USA           2525 1982-01-01
#   380                    pontiac phoenix     USA           2735 1982-01-01
#   381               ford fairmont futura     USA           2865 1982-01-01
#   382                     amc concord dl     USA           3035 1982-01-01
#   383                volkswagen rabbit l  Europe           1980 1982-01-01
#   384                 mazda glc custom l   Japan           2025 1982-01-01
#   385                   mazda glc custom   Japan           1970 1982-01-01
#   386             plymouth horizon miser     USA           2125 1982-01-01
#   387                     mercury lynx l     USA           2125 1982-01-01
#   388                   nissan stanza xe   Japan           2160 1982-01-01
#   389              honda Accelerationord   Japan           2205 1982-01-01
#   390                     toyota corolla   Japan           2245 1982-01-01
#   391                        honda civic   Japan           1965 1982-01-01
#   392                 honda civic (auto)   Japan           1965 1982-01-01
#   393                      datsun 310 gx   Japan           1995 1982-01-01
#   394              buick century limited     USA           2945 1982-01-01
#   395  oldsmobile cutlass ciera (diesel)     USA           3015 1982-01-01
#   396         chrysler lebaron medallion     USA           2585 1982-01-01
#   397                     ford granada l     USA           2835 1982-01-01
#   398                   toyota celica gt   Japan           2665 1982-01-01
#   399                  dodge charger 2.2     USA           2370 1982-01-01
#   400                   chevrolet camaro     USA           2950 1982-01-01
#   401                    ford mustang gl     USA           2790 1982-01-01
#   402                          vw pickup  Europe           2130 1982-01-01
#   403                      dodge rampage     USA           2295 1982-01-01
#   404                        ford ranger     USA           2625 1982-01-01
#   405                         chevy s-10     USA           2720 1982-01-01
#
#   [406 rows x 9 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'average(Acceleration):Q'
#     }),
#     size: Size({
#       shorthand: 'count()'
#     }),
#     x: X({
#       bin: True,
#       shorthand: 'Horsepower',
#       title: 'Horsepower'
#     }),
#     y: Y({
#       bin: True,
#       shorthand: 'Miles_per_Gallon'
#     })
#   }),
#   mark: 'point'
# })

# %%
barley=data.barley()

alt.Chart(barley).mark_bar().encode(
    x='variety:N',
    y='sum(yield):Q',
    color='site:N',
    order=alt.Order('site', sort='ascending')
)
# Out:
# Chart({
#   data:                 site           variety  year     yield
#   0    University Farm         Manchuria  1931  27.00000
#   1             Waseca         Manchuria  1931  48.86667
#   2             Morris         Manchuria  1931  27.43334
#   3          Crookston         Manchuria  1931  39.93333
#   4       Grand Rapids         Manchuria  1931  32.96667
#   5             Duluth         Manchuria  1931  28.96667
#   6    University Farm           Glabron  1931  43.06666
#   7             Waseca           Glabron  1931  55.20000
#   8             Morris           Glabron  1931  28.76667
#   9          Crookston           Glabron  1931  38.13333
#   10      Grand Rapids           Glabron  1931  29.13333
#   11            Duluth           Glabron  1931  29.66667
#   12   University Farm          Svansota  1931  35.13333
#   13            Waseca          Svansota  1931  47.33333
#   14            Morris          Svansota  1931  25.76667
#   15         Crookston          Svansota  1931  40.46667
#   16      Grand Rapids          Svansota  1931  29.66667
#   17            Duluth          Svansota  1931  25.70000
#   18   University Farm            Velvet  1931  39.90000
#   19            Waseca            Velvet  1931  50.23333
#   20            Morris            Velvet  1931  26.13333
#   21         Crookston            Velvet  1931  41.33333
#   22      Grand Rapids            Velvet  1931  23.03333
#   23            Duluth            Velvet  1931  26.30000
#   24   University Farm             Trebi  1931  36.56666
#   25            Waseca             Trebi  1931  63.83330
#   26            Morris             Trebi  1931  43.76667
#   27         Crookston             Trebi  1931  46.93333
#   28      Grand Rapids             Trebi  1931  29.76667
#   29            Duluth             Trebi  1931  33.93333
#   ..               ...               ...   ...       ...
#   90   University Farm           No. 457  1932  26.43334
#   91            Waseca           No. 457  1932  42.20000
#   92            Morris           No. 457  1932  43.53334
#   93         Crookston           No. 457  1932  34.33333
#   94      Grand Rapids           No. 457  1932  19.46667
#   95            Duluth           No. 457  1932  22.70000
#   96   University Farm           No. 462  1932  25.56667
#   97            Waseca           No. 462  1932  44.70000
#   98            Morris           No. 462  1932  47.00000
#   99         Crookston           No. 462  1932  30.53333
#   100     Grand Rapids           No. 462  1932  19.90000
#   101           Duluth           No. 462  1932  22.50000
#   102  University Farm          Peatland  1932  28.06667
#   103           Waseca          Peatland  1932  36.03333
#   104           Morris          Peatland  1932  43.20000
#   105        Crookston          Peatland  1932  25.23333
#   106     Grand Rapids          Peatland  1932  26.76667
#   107           Duluth          Peatland  1932  31.36667
#   108  University Farm           No. 475  1932  30.00000
#   109           Waseca           No. 475  1932  41.26667
#   110           Morris           No. 475  1932  44.23333
#   111        Crookston           No. 475  1932  32.13333
#   112     Grand Rapids           No. 475  1932  15.23333
#   113           Duluth           No. 475  1932  27.36667
#   114  University Farm  Wisconsin No. 38  1932  38.00000
#   115           Waseca  Wisconsin No. 38  1932  58.16667
#   116           Morris  Wisconsin No. 38  1932  47.16667
#   117        Crookston  Wisconsin No. 38  1932  35.90000
#   118     Grand Rapids  Wisconsin No. 38  1932  20.66667
#   119           Duluth  Wisconsin No. 38  1932  29.33333
#
#   [120 rows x 4 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'site:N'
#     }),
#     order: Order({
#       shorthand: 'site',
#       sort: 'ascending'
#     }),
#     x: X({
#       shorthand: 'variety:N'
#     }),
#     y: Y({
#       shorthand: 'sum(yield):Q'
#     })
#   }),
#   mark: 'bar'
# })

# %%
alt.Chart(barley).mark_area().encode(
    x='variety:N',
    y='sum(yield):Q',
    color='site:N',
    order=alt.Order('site', sort='ascending')
)
# Out:
# Chart({
#   data:                 site           variety  year     yield
#   0    University Farm         Manchuria  1931  27.00000
#   1             Waseca         Manchuria  1931  48.86667
#   2             Morris         Manchuria  1931  27.43334
#   3          Crookston         Manchuria  1931  39.93333
#   4       Grand Rapids         Manchuria  1931  32.96667
#   5             Duluth         Manchuria  1931  28.96667
#   6    University Farm           Glabron  1931  43.06666
#   7             Waseca           Glabron  1931  55.20000
#   8             Morris           Glabron  1931  28.76667
#   9          Crookston           Glabron  1931  38.13333
#   10      Grand Rapids           Glabron  1931  29.13333
#   11            Duluth           Glabron  1931  29.66667
#   12   University Farm          Svansota  1931  35.13333
#   13            Waseca          Svansota  1931  47.33333
#   14            Morris          Svansota  1931  25.76667
#   15         Crookston          Svansota  1931  40.46667
#   16      Grand Rapids          Svansota  1931  29.66667
#   17            Duluth          Svansota  1931  25.70000
#   18   University Farm            Velvet  1931  39.90000
#   19            Waseca            Velvet  1931  50.23333
#   20            Morris            Velvet  1931  26.13333
#   21         Crookston            Velvet  1931  41.33333
#   22      Grand Rapids            Velvet  1931  23.03333
#   23            Duluth            Velvet  1931  26.30000
#   24   University Farm             Trebi  1931  36.56666
#   25            Waseca             Trebi  1931  63.83330
#   26            Morris             Trebi  1931  43.76667
#   27         Crookston             Trebi  1931  46.93333
#   28      Grand Rapids             Trebi  1931  29.76667
#   29            Duluth             Trebi  1931  33.93333
#   ..               ...               ...   ...       ...
#   90   University Farm           No. 457  1932  26.43334
#   91            Waseca           No. 457  1932  42.20000
#   92            Morris           No. 457  1932  43.53334
#   93         Crookston           No. 457  1932  34.33333
#   94      Grand Rapids           No. 457  1932  19.46667
#   95            Duluth           No. 457  1932  22.70000
#   96   University Farm           No. 462  1932  25.56667
#   97            Waseca           No. 462  1932  44.70000
#   98            Morris           No. 462  1932  47.00000
#   99         Crookston           No. 462  1932  30.53333
#   100     Grand Rapids           No. 462  1932  19.90000
#   101           Duluth           No. 462  1932  22.50000
#   102  University Farm          Peatland  1932  28.06667
#   103           Waseca          Peatland  1932  36.03333
#   104           Morris          Peatland  1932  43.20000
#   105        Crookston          Peatland  1932  25.23333
#   106     Grand Rapids          Peatland  1932  26.76667
#   107           Duluth          Peatland  1932  31.36667
#   108  University Farm           No. 475  1932  30.00000
#   109           Waseca           No. 475  1932  41.26667
#   110           Morris           No. 475  1932  44.23333
#   111        Crookston           No. 475  1932  32.13333
#   112     Grand Rapids           No. 475  1932  15.23333
#   113           Duluth           No. 475  1932  27.36667
#   114  University Farm  Wisconsin No. 38  1932  38.00000
#   115           Waseca  Wisconsin No. 38  1932  58.16667
#   116           Morris  Wisconsin No. 38  1932  47.16667
#   117        Crookston  Wisconsin No. 38  1932  35.90000
#   118     Grand Rapids  Wisconsin No. 38  1932  20.66667
#   119           Duluth  Wisconsin No. 38  1932  29.33333
#
#   [120 rows x 4 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'site:N'
#     }),
#     order: Order({
#       shorthand: 'site',
#       sort: 'ascending'
#     }),
#     x: X({
#       shorthand: 'variety:N'
#     }),
#     y: Y({
#       shorthand: 'sum(yield):Q'
#     })
#   }),
#   mark: 'area'
# })

# %%
driving=data.driving()
driving.head()
# Out:
#     gas  miles    side  year
# 0  2.38   3675    left  1956
# 1  2.40   3706   right  1957
# 2  2.26   3766  bottom  1958
# 3  2.31   3905     top  1959
# 4  2.27   3935   right  1960

# %%
alt.Chart(driving).mark_line(point=True).encode(
    alt.X('miles', scale=alt.Scale(zero=False)),
    alt.Y('gas', scale=alt.Scale(zero=False)),
    order='year'

)
# Out:
# Chart({
#   data:      gas  miles    side  year
#   0   2.38   3675    left  1956
#   1   2.40   3706   right  1957
#   2   2.26   3766  bottom  1958
#   3   2.31   3905     top  1959
#   4   2.27   3935   right  1960
#   5   2.25   3977  bottom  1961
#   6   2.22   4085   right  1962
#   7   2.12   4218  bottom  1963
#   8   2.11   4369  bottom  1964
#   9   2.14   4538  bottom  1965
#   10  2.14   4676     top  1966
#   11  2.14   4827  bottom  1967
#   12  2.13   5038   right  1968
#   13  2.07   5207   right  1969
#   14  2.01   5376   right  1970
#   15  1.93   5617  bottom  1971
#   16  1.87   5973  bottom  1972
#   17  1.90   6154   right  1973
#   18  2.34   5943    left  1974
#   19  2.31   6111  bottom  1975
#   20  2.32   6389  bottom  1976
#   21  2.36   6630     top  1977
#   22  2.23   6883  bottom  1978
#   23  2.68   6744    left  1979
#   24  3.30   6672    left  1980
#   25  3.30   6732   right  1981
#   26  2.92   6835   right  1982
#   27  2.66   6943   right  1983
#   28  2.48   7130   right  1984
#   29  2.36   7323   right  1985
#   30  1.76   7558    left  1986
#   31  1.76   7770     top  1987
#   32  1.68   8089  bottom  1988
#   33  1.75   8397    left  1989
#   34  1.88   8529     top  1990
#   35  1.78   8535   right  1991
#   36  1.69   8662   right  1992
#   37  1.60   8855    left  1993
#   38  1.59   8909  bottom  1994
#   39  1.60   9150  bottom  1995
#   40  1.67   9192     top  1996
#   41  1.65   9416   right  1997
#   42  1.39   9590  bottom  1998
#   43  1.50   9687   right  1999
#   44  1.89   9717     top  2000
#   45  1.77   9699    left  2001
#   46  1.64   9814  bottom  2002
#   47  1.86   9868   right  2003
#   48  2.14   9994    left  2004
#   49  2.53  10067    left  2005
#   50  2.79  10037   right  2006
#   51  2.95  10025   right  2007
#   52  3.31   9880    left  2008
#   53  2.38   9657  bottom  2009
#   54  2.61   9596    left  2010,
#   encoding: EncodingWithFacet({
#     order: Order({
#       shorthand: 'year'
#     }),
#     x: X({
#       scale: Scale({
#         zero: False
#       }),
#       shorthand: 'miles'
#     }),
#     y: Y({
#       scale: Scale({
#         zero: False
#       }),
#       shorthand: 'gas'
#     })
#   }),
#   mark: MarkDef({
#     point: True,
#     type: 'line'
#   })
# })

# %%
base=alt.Chart(barley).mark_bar().encode(
y='mean(yield):Q',
color=alt.Color('mean(yield):Q', legend=None)).properties(width=100, height=100)

# %%
# Sort x in ascending order
ascending = base.encode(
x=alt.X('site', type='nominal', sort='ascending')
).properties(title='Ascending')

# Sort x in descending order
descending = base.encode(
x=alt.X('site', type='nominal', sort='descending')
).properties(title='Descending')

# Sort x in an explicitly-specified order
explicit = base.encode(
x=alt.X('site', type='nominal', 
        sort = ['Duluth', 'Grand Rapids', 'Morris',
                'University Farm', 'Waseca', 'Crookston'])
).properties(title='Explicit')

# Sort according to another field
sortfield = base.encode(
x=alt.X('site', type='nominal', sort=alt.EncodingSortField(field='yield', op='mean'))
).properties(title='By Yield')


ascending|descending|explicit|sortfield
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                 site           variety  year     yield
#     0    University Farm         Manchuria  1931  27.00000
#     1             Waseca         Manchuria  1931  48.86667
#     2             Morris         Manchuria  1931  27.43334
#     3          Crookston         Manchuria  1931  39.93333
#     4       Grand Rapids         Manchuria  1931  32.96667
#     5             Duluth         Manchuria  1931  28.96667
#     6    University Farm           Glabron  1931  43.06666
#     7             Waseca           Glabron  1931  55.20000
#     8             Morris           Glabron  1931  28.76667
#     9          Crookston           Glabron  1931  38.13333
#     10      Grand Rapids           Glabron  1931  29.13333
#     11            Duluth           Glabron  1931  29.66667
#     12   University Farm          Svansota  1931  35.13333
#     13            Waseca          Svansota  1931  47.33333
#     14            Morris          Svansota  1931  25.76667
#     15         Crookston          Svansota  1931  40.46667
#     16      Grand Rapids          Svansota  1931  29.66667
#     17            Duluth          Svansota  1931  25.70000
#     18   University Farm            Velvet  1931  39.90000
#     19            Waseca            Velvet  1931  50.23333
#     20            Morris            Velvet  1931  26.13333
#     21         Crookston            Velvet  1931  41.33333
#     22      Grand Rapids            Velvet  1931  23.03333
#     23            Duluth            Velvet  1931  26.30000
#     24   University Farm             Trebi  1931  36.56666
#     25            Waseca             Trebi  1931  63.83330
#     26            Morris             Trebi  1931  43.76667
#     27         Crookston             Trebi  1931  46.93333
#     28      Grand Rapids             Trebi  1931  29.76667
#     29            Duluth             Trebi  1931  33.93333
#     ..               ...               ...   ...       ...
#     90   University Farm           No. 457  1932  26.43334
#     91            Waseca           No. 457  1932  42.20000
#     92            Morris           No. 457  1932  43.53334
#     93         Crookston           No. 457  1932  34.33333
#     94      Grand Rapids           No. 457  1932  19.46667
#     95            Duluth           No. 457  1932  22.70000
#     96   University Farm           No. 462  1932  25.56667
#     97            Waseca           No. 462  1932  44.70000
#     98            Morris           No. 462  1932  47.00000
#     99         Crookston           No. 462  1932  30.53333
#     100     Grand Rapids           No. 462  1932  19.90000
#     101           Duluth           No. 462  1932  22.50000
#     102  University Farm          Peatland  1932  28.06667
#     103           Waseca          Peatland  1932  36.03333
#     104           Morris          Peatland  1932  43.20000
#     105        Crookston          Peatland  1932  25.23333
#     106     Grand Rapids          Peatland  1932  26.76667
#     107           Duluth          Peatland  1932  31.36667
#     108  University Farm           No. 475  1932  30.00000
#     109           Waseca           No. 475  1932  41.26667
#     110           Morris           No. 475  1932  44.23333
#     111        Crookston           No. 475  1932  32.13333
#     112     Grand Rapids           No. 475  1932  15.23333
#     113           Duluth           No. 475  1932  27.36667
#     114  University Farm  Wisconsin No. 38  1932  38.00000
#     115           Waseca  Wisconsin No. 38  1932  58.16667
#     116           Morris  Wisconsin No. 38  1932  47.16667
#     117        Crookston  Wisconsin No. 38  1932  35.90000
#     118     Grand Rapids  Wisconsin No. 38  1932  20.66667
#     119           Duluth  Wisconsin No. 38  1932  29.33333
#
#     [120 rows x 4 columns],
#     encoding: EncodingWithFacet({
#       color: Color({
#         legend: None,
#         shorthand: 'mean(yield):Q'
#       }),
#       x: X({
#         shorthand: 'site',
#         sort: 'ascending',
#         type: 'nominal'
#       }),
#       y: Y({
#         shorthand: 'mean(yield):Q'
#       })
#     }),
#     height: 100,
#     mark: 'bar',
#     title: 'Ascending',
#     width: 100
#   }), Chart({
#     data:                 site           variety  year     yield
#     0    University Farm         Manchuria  1931  27.00000
#     1             Waseca         Manchuria  1931  48.86667
#     2             Morris         Manchuria  1931  27.43334
#     3          Crookston         Manchuria  1931  39.93333
#     4       Grand Rapids         Manchuria  1931  32.96667
#     5             Duluth         Manchuria  1931  28.96667
#     6    University Farm           Glabron  1931  43.06666
#     7             Waseca           Glabron  1931  55.20000
#     8             Morris           Glabron  1931  28.76667
#     9          Crookston           Glabron  1931  38.13333
#     10      Grand Rapids           Glabron  1931  29.13333
#     11            Duluth           Glabron  1931  29.66667
#     12   University Farm          Svansota  1931  35.13333
#     13            Waseca          Svansota  1931  47.33333
#     14            Morris          Svansota  1931  25.76667
#     15         Crookston          Svansota  1931  40.46667
#     16      Grand Rapids          Svansota  1931  29.66667
#     17            Duluth          Svansota  1931  25.70000
#     18   University Farm            Velvet  1931  39.90000
#     19            Waseca            Velvet  1931  50.23333
#     20            Morris            Velvet  1931  26.13333
#     21         Crookston            Velvet  1931  41.33333
#     22      Grand Rapids            Velvet  1931  23.03333
#     23            Duluth            Velvet  1931  26.30000
#     24   University Farm             Trebi  1931  36.56666
#     25            Waseca             Trebi  1931  63.83330
#     26            Morris             Trebi  1931  43.76667
#     27         Crookston             Trebi  1931  46.93333
#     28      Grand Rapids             Trebi  1931  29.76667
#     29            Duluth             Trebi  1931  33.93333
#     ..               ...               ...   ...       ...
#     90   University Farm           No. 457  1932  26.43334
#     91            Waseca           No. 457  1932  42.20000
#     92            Morris           No. 457  1932  43.53334
#     93         Crookston           No. 457  1932  34.33333
#     94      Grand Rapids           No. 457  1932  19.46667
#     95            Duluth           No. 457  1932  22.70000
#     96   University Farm           No. 462  1932  25.56667
#     97            Waseca           No. 462  1932  44.70000
#     98            Morris           No. 462  1932  47.00000
#     99         Crookston           No. 462  1932  30.53333
#     100     Grand Rapids           No. 462  1932  19.90000
#     101           Duluth           No. 462  1932  22.50000
#     102  University Farm          Peatland  1932  28.06667
#     103           Waseca          Peatland  1932  36.03333
#     104           Morris          Peatland  1932  43.20000
#     105        Crookston          Peatland  1932  25.23333
#     106     Grand Rapids          Peatland  1932  26.76667
#     107           Duluth          Peatland  1932  31.36667
#     108  University Farm           No. 475  1932  30.00000
#     109           Waseca           No. 475  1932  41.26667
#     110           Morris           No. 475  1932  44.23333
#     111        Crookston           No. 475  1932  32.13333
#     112     Grand Rapids           No. 475  1932  15.23333
#     113           Duluth           No. 475  1932  27.36667
#     114  University Farm  Wisconsin No. 38  1932  38.00000
#     115           Waseca  Wisconsin No. 38  1932  58.16667
#     116           Morris  Wisconsin No. 38  1932  47.16667
#     117        Crookston  Wisconsin No. 38  1932  35.90000
#     118     Grand Rapids  Wisconsin No. 38  1932  20.66667
#     119           Duluth  Wisconsin No. 38  1932  29.33333
#
#     [120 rows x 4 columns],
#     encoding: EncodingWithFacet({
#       color: Color({
#         legend: None,
#         shorthand: 'mean(yield):Q'
#       }),
#       x: X({
#         shorthand: 'site',
#         sort: 'descending',
#         type: 'nominal'
#       }),
#       y: Y({
#         shorthand: 'mean(yield):Q'
#       })
#     }),
#     height: 100,
#     mark: 'bar',
#     title: 'Descending',
#     width: 100
#   }), Chart({
#     data:                 site           variety  year     yield
#     0    University Farm         Manchuria  1931  27.00000
#     1             Waseca         Manchuria  1931  48.86667
#     2             Morris         Manchuria  1931  27.43334
#     3          Crookston         Manchuria  1931  39.93333
#     4       Grand Rapids         Manchuria  1931  32.96667
#     5             Duluth         Manchuria  1931  28.96667
#     6    University Farm           Glabron  1931  43.06666
#     7             Waseca           Glabron  1931  55.20000
#     8             Morris           Glabron  1931  28.76667
#     9          Crookston           Glabron  1931  38.13333
#     10      Grand Rapids           Glabron  1931  29.13333
#     11            Duluth           Glabron  1931  29.66667
#     12   University Farm          Svansota  1931  35.13333
#     13            Waseca          Svansota  1931  47.33333
#     14            Morris          Svansota  1931  25.76667
#     15         Crookston          Svansota  1931  40.46667
#     16      Grand Rapids          Svansota  1931  29.66667
#     17            Duluth          Svansota  1931  25.70000
#     18   University Farm            Velvet  1931  39.90000
#     19            Waseca            Velvet  1931  50.23333
#     20            Morris            Velvet  1931  26.13333
#     21         Crookston            Velvet  1931  41.33333
#     22      Grand Rapids            Velvet  1931  23.03333
#     23            Duluth            Velvet  1931  26.30000
#     24   University Farm             Trebi  1931  36.56666
#     25            Waseca             Trebi  1931  63.83330
#     26            Morris             Trebi  1931  43.76667
#     27         Crookston             Trebi  1931  46.93333
#     28      Grand Rapids             Trebi  1931  29.76667
#     29            Duluth             Trebi  1931  33.93333
#     ..               ...               ...   ...       ...
#     90   University Farm           No. 457  1932  26.43334
#     91            Waseca           No. 457  1932  42.20000
#     92            Morris           No. 457  1932  43.53334
#     93         Crookston           No. 457  1932  34.33333
#     94      Grand Rapids           No. 457  1932  19.46667
#     95            Duluth           No. 457  1932  22.70000
#     96   University Farm           No. 462  1932  25.56667
#     97            Waseca           No. 462  1932  44.70000
#     98            Morris           No. 462  1932  47.00000
#     99         Crookston           No. 462  1932  30.53333
#     100     Grand Rapids           No. 462  1932  19.90000
#     101           Duluth           No. 462  1932  22.50000
#     102  University Farm          Peatland  1932  28.06667
#     103           Waseca          Peatland  1932  36.03333
#     104           Morris          Peatland  1932  43.20000
#     105        Crookston          Peatland  1932  25.23333
#     106     Grand Rapids          Peatland  1932  26.76667
#     107           Duluth          Peatland  1932  31.36667
#     108  University Farm           No. 475  1932  30.00000
#     109           Waseca           No. 475  1932  41.26667
#     110           Morris           No. 475  1932  44.23333
#     111        Crookston           No. 475  1932  32.13333
#     112     Grand Rapids           No. 475  1932  15.23333
#     113           Duluth           No. 475  1932  27.36667
#     114  University Farm  Wisconsin No. 38  1932  38.00000
#     115           Waseca  Wisconsin No. 38  1932  58.16667
#     116           Morris  Wisconsin No. 38  1932  47.16667
#     117        Crookston  Wisconsin No. 38  1932  35.90000
#     118     Grand Rapids  Wisconsin No. 38  1932  20.66667
#     119           Duluth  Wisconsin No. 38  1932  29.33333
#
#     [120 rows x 4 columns],
#     encoding: EncodingWithFacet({
#       color: Color({
#         legend: None,
#         shorthand: 'mean(yield):Q'
#       }),
#       x: X({
#         shorthand: 'site',
#         sort: ['Duluth', 'Grand Rapids', 'Morris', 'University Farm', 'Waseca', 'Crookston'],
#         type: 'nominal'
#       }),
#       y: Y({
#         shorthand: 'mean(yield):Q'
#       })
#     }),
#     height: 100,
#     mark: 'bar',
#     title: 'Explicit',
#     width: 100
#   }), Chart({
#     data:                 site           variety  year     yield
#     0    University Farm         Manchuria  1931  27.00000
#     1             Waseca         Manchuria  1931  48.86667
#     2             Morris         Manchuria  1931  27.43334
#     3          Crookston         Manchuria  1931  39.93333
#     4       Grand Rapids         Manchuria  1931  32.96667
#     5             Duluth         Manchuria  1931  28.96667
#     6    University Farm           Glabron  1931  43.06666
#     7             Waseca           Glabron  1931  55.20000
#     8             Morris           Glabron  1931  28.76667
#     9          Crookston           Glabron  1931  38.13333
#     10      Grand Rapids           Glabron  1931  29.13333
#     11            Duluth           Glabron  1931  29.66667
#     12   University Farm          Svansota  1931  35.13333
#     13            Waseca          Svansota  1931  47.33333
#     14            Morris          Svansota  1931  25.76667
#     15         Crookston          Svansota  1931  40.46667
#     16      Grand Rapids          Svansota  1931  29.66667
#     17            Duluth          Svansota  1931  25.70000
#     18   University Farm            Velvet  1931  39.90000
#     19            Waseca            Velvet  1931  50.23333
#     20            Morris            Velvet  1931  26.13333
#     21         Crookston            Velvet  1931  41.33333
#     22      Grand Rapids            Velvet  1931  23.03333
#     23            Duluth            Velvet  1931  26.30000
#     24   University Farm             Trebi  1931  36.56666
#     25            Waseca             Trebi  1931  63.83330
#     26            Morris             Trebi  1931  43.76667
#     27         Crookston             Trebi  1931  46.93333
#     28      Grand Rapids             Trebi  1931  29.76667
#     29            Duluth             Trebi  1931  33.93333
#     ..               ...               ...   ...       ...
#     90   University Farm           No. 457  1932  26.43334
#     91            Waseca           No. 457  1932  42.20000
#     92            Morris           No. 457  1932  43.53334
#     93         Crookston           No. 457  1932  34.33333
#     94      Grand Rapids           No. 457  1932  19.46667
#     95            Duluth           No. 457  1932  22.70000
#     96   University Farm           No. 462  1932  25.56667
#     97            Waseca           No. 462  1932  44.70000
#     98            Morris           No. 462  1932  47.00000
#     99         Crookston           No. 462  1932  30.53333
#     100     Grand Rapids           No. 462  1932  19.90000
#     101           Duluth           No. 462  1932  22.50000
#     102  University Farm          Peatland  1932  28.06667
#     103           Waseca          Peatland  1932  36.03333
#     104           Morris          Peatland  1932  43.20000
#     105        Crookston          Peatland  1932  25.23333
#     106     Grand Rapids          Peatland  1932  26.76667
#     107           Duluth          Peatland  1932  31.36667
#     108  University Farm           No. 475  1932  30.00000
#     109           Waseca           No. 475  1932  41.26667
#     110           Morris           No. 475  1932  44.23333
#     111        Crookston           No. 475  1932  32.13333
#     112     Grand Rapids           No. 475  1932  15.23333
#     113           Duluth           No. 475  1932  27.36667
#     114  University Farm  Wisconsin No. 38  1932  38.00000
#     115           Waseca  Wisconsin No. 38  1932  58.16667
#     116           Morris  Wisconsin No. 38  1932  47.16667
#     117        Crookston  Wisconsin No. 38  1932  35.90000
#     118     Grand Rapids  Wisconsin No. 38  1932  20.66667
#     119           Duluth  Wisconsin No. 38  1932  29.33333
#
#     [120 rows x 4 columns],
#     encoding: EncodingWithFacet({
#       color: Color({
#         legend: None,
#         shorthand: 'mean(yield):Q'
#       }),
#       x: X({
#         shorthand: 'site',
#         sort: EncodingSortField({
#           field: 'yield',
#           op: 'mean'
#         }),
#         type: 'nominal'
#       }),
#       y: Y({
#         shorthand: 'mean(yield):Q'
#       })
#     }),
#     height: 100,
#     mark: 'bar',
#     title: 'By Yield',
#     width: 100
#   })]
# })

# %%
alt.Chart(barley).mark_rect().encode(
alt.X('mean(yield):Q', sort='ascending'),
alt.Y('site:N', sort='descending'),
alt.Color('site:N',
sort=['Morris', 'Duluth', 'Grand Rapids',
              'University Farm', 'Waseca', 'Crookston']), 

)
# Out:
# Chart({
#   data:                 site           variety  year     yield
#   0    University Farm         Manchuria  1931  27.00000
#   1             Waseca         Manchuria  1931  48.86667
#   2             Morris         Manchuria  1931  27.43334
#   3          Crookston         Manchuria  1931  39.93333
#   4       Grand Rapids         Manchuria  1931  32.96667
#   5             Duluth         Manchuria  1931  28.96667
#   6    University Farm           Glabron  1931  43.06666
#   7             Waseca           Glabron  1931  55.20000
#   8             Morris           Glabron  1931  28.76667
#   9          Crookston           Glabron  1931  38.13333
#   10      Grand Rapids           Glabron  1931  29.13333
#   11            Duluth           Glabron  1931  29.66667
#   12   University Farm          Svansota  1931  35.13333
#   13            Waseca          Svansota  1931  47.33333
#   14            Morris          Svansota  1931  25.76667
#   15         Crookston          Svansota  1931  40.46667
#   16      Grand Rapids          Svansota  1931  29.66667
#   17            Duluth          Svansota  1931  25.70000
#   18   University Farm            Velvet  1931  39.90000
#   19            Waseca            Velvet  1931  50.23333
#   20            Morris            Velvet  1931  26.13333
#   21         Crookston            Velvet  1931  41.33333
#   22      Grand Rapids            Velvet  1931  23.03333
#   23            Duluth            Velvet  1931  26.30000
#   24   University Farm             Trebi  1931  36.56666
#   25            Waseca             Trebi  1931  63.83330
#   26            Morris             Trebi  1931  43.76667
#   27         Crookston             Trebi  1931  46.93333
#   28      Grand Rapids             Trebi  1931  29.76667
#   29            Duluth             Trebi  1931  33.93333
#   ..               ...               ...   ...       ...
#   90   University Farm           No. 457  1932  26.43334
#   91            Waseca           No. 457  1932  42.20000
#   92            Morris           No. 457  1932  43.53334
#   93         Crookston           No. 457  1932  34.33333
#   94      Grand Rapids           No. 457  1932  19.46667
#   95            Duluth           No. 457  1932  22.70000
#   96   University Farm           No. 462  1932  25.56667
#   97            Waseca           No. 462  1932  44.70000
#   98            Morris           No. 462  1932  47.00000
#   99         Crookston           No. 462  1932  30.53333
#   100     Grand Rapids           No. 462  1932  19.90000
#   101           Duluth           No. 462  1932  22.50000
#   102  University Farm          Peatland  1932  28.06667
#   103           Waseca          Peatland  1932  36.03333
#   104           Morris          Peatland  1932  43.20000
#   105        Crookston          Peatland  1932  25.23333
#   106     Grand Rapids          Peatland  1932  26.76667
#   107           Duluth          Peatland  1932  31.36667
#   108  University Farm           No. 475  1932  30.00000
#   109           Waseca           No. 475  1932  41.26667
#   110           Morris           No. 475  1932  44.23333
#   111        Crookston           No. 475  1932  32.13333
#   112     Grand Rapids           No. 475  1932  15.23333
#   113           Duluth           No. 475  1932  27.36667
#   114  University Farm  Wisconsin No. 38  1932  38.00000
#   115           Waseca  Wisconsin No. 38  1932  58.16667
#   116           Morris  Wisconsin No. 38  1932  47.16667
#   117        Crookston  Wisconsin No. 38  1932  35.90000
#   118     Grand Rapids  Wisconsin No. 38  1932  20.66667
#   119           Duluth  Wisconsin No. 38  1932  29.33333
#
#   [120 rows x 4 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'site:N',
#       sort: ['Morris', 'Duluth', 'Grand Rapids', 'University Farm', 'Waseca', 'Crookston']
#     }),
#     x: X({
#       shorthand: 'mean(yield):Q',
#       sort: 'ascending'
#     }),
#     y: Y({
#       shorthand: 'site:N',
#       sort: 'descending'
#     })
#   }),
#   mark: 'rect'
# })

# %% [markdown]
# **Marks**

# %%
import altair as alt
from vega_datasets import data

iris = data.iris()

alt.Chart(iris).mark_point().encode(
    x='petalLength',
    y='petalWidth',
    color='species'
)
# Out:
# Chart({
#   data:      petalLength  petalWidth  sepalLength  sepalWidth    species
#   0            1.4         0.2          5.1         3.5     setosa
#   1            1.4         0.2          4.9         3.0     setosa
#   2            1.3         0.2          4.7         3.2     setosa
#   3            1.5         0.2          4.6         3.1     setosa
#   4            1.4         0.2          5.0         3.6     setosa
#   5            1.7         0.4          5.4         3.9     setosa
#   6            1.4         0.3          4.6         3.4     setosa
#   7            1.5         0.2          5.0         3.4     setosa
#   8            1.4         0.2          4.4         2.9     setosa
#   9            1.5         0.1          4.9         3.1     setosa
#   10           1.5         0.2          5.4         3.7     setosa
#   11           1.6         0.2          4.8         3.4     setosa
#   12           1.4         0.1          4.8         3.0     setosa
#   13           1.1         0.1          4.3         3.0     setosa
#   14           1.2         0.2          5.8         4.0     setosa
#   15           1.5         0.4          5.7         4.4     setosa
#   16           1.3         0.4          5.4         3.9     setosa
#   17           1.4         0.3          5.1         3.5     setosa
#   18           1.7         0.3          5.7         3.8     setosa
#   19           1.5         0.3          5.1         3.8     setosa
#   20           1.7         0.2          5.4         3.4     setosa
#   21           1.5         0.4          5.1         3.7     setosa
#   22           1.0         0.2          4.6         3.6     setosa
#   23           1.7         0.5          5.1         3.3     setosa
#   24           1.9         0.2          4.8         3.4     setosa
#   25           1.6         0.2          5.0         3.0     setosa
#   26           1.6         0.4          5.0         3.4     setosa
#   27           1.5         0.2          5.2         3.5     setosa
#   28           1.4         0.2          5.2         3.4     setosa
#   29           1.6         0.2          4.7         3.2     setosa
#   ..           ...         ...          ...         ...        ...
#   120          5.7         2.3          6.9         3.2  virginica
#   121          4.9         2.0          5.6         2.8  virginica
#   122          6.7         2.0          7.7         2.8  virginica
#   123          4.9         1.8          6.3         2.7  virginica
#   124          5.7         2.1          6.7         3.3  virginica
#   125          6.0         1.8          7.2         3.2  virginica
#   126          4.8         1.8          6.2         2.8  virginica
#   127          4.9         1.8          6.1         3.0  virginica
#   128          5.6         2.1          6.4         2.8  virginica
#   129          5.8         1.6          7.2         3.0  virginica
#   130          6.1         1.9          7.4         2.8  virginica
#   131          6.4         2.0          7.9         3.8  virginica
#   132          5.6         2.2          6.4         2.8  virginica
#   133          5.1         1.5          6.3         2.8  virginica
#   134          5.6         1.4          6.1         2.6  virginica
#   135          6.1         2.3          7.7         3.0  virginica
#   136          5.6         2.4          6.3         3.4  virginica
#   137          5.5         1.8          6.4         3.1  virginica
#   138          4.8         1.8          6.0         3.0  virginica
#   139          5.4         2.1          6.9         3.1  virginica
#   140          5.6         2.4          6.7         3.1  virginica
#   141          5.1         2.3          6.9         3.1  virginica
#   142          5.1         1.9          5.8         2.7  virginica
#   143          5.9         2.3          6.8         3.2  virginica
#   144          5.7         2.5          6.7         3.3  virginica
#   145          5.2         2.3          6.7         3.0  virginica
#   146          5.0         1.9          6.3         2.5  virginica
#   147          5.2         2.0          6.5         3.0  virginica
#   148          5.4         2.3          6.2         3.4  virginica
#   149          5.1         1.8          5.9         3.0  virginica
#
#   [150 rows x 5 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'species'
#     }),
#     x: X({
#       shorthand: 'petalLength'
#     }),
#     y: Y({
#       shorthand: 'petalWidth'
#     })
#   }),
#   mark: 'point'
# })

# %%
import altair as alt
from vega_datasets import data

source = data.stocks()

alt.Chart(source).mark_line(point=True).encode(
    x='date:T',
    y='price:Q',
    color='symbol:N'
)
# Out:
# Chart({
#   data:     symbol       date   price
#   0     MSFT 2000-01-01   39.81
#   1     MSFT 2000-02-01   36.35
#   2     MSFT 2000-03-01   43.22
#   3     MSFT 2000-04-01   28.37
#   4     MSFT 2000-05-01   25.45
#   5     MSFT 2000-06-01   32.54
#   6     MSFT 2000-07-01   28.40
#   7     MSFT 2000-08-01   28.40
#   8     MSFT 2000-09-01   24.53
#   9     MSFT 2000-10-01   28.02
#   10    MSFT 2000-11-01   23.34
#   11    MSFT 2000-12-01   17.65
#   12    MSFT 2001-01-01   24.84
#   13    MSFT 2001-02-01   24.00
#   14    MSFT 2001-03-01   22.25
#   15    MSFT 2001-04-01   27.56
#   16    MSFT 2001-05-01   28.14
#   17    MSFT 2001-06-01   29.70
#   18    MSFT 2001-07-01   26.93
#   19    MSFT 2001-08-01   23.21
#   20    MSFT 2001-09-01   20.82
#   21    MSFT 2001-10-01   23.65
#   22    MSFT 2001-11-01   26.12
#   23    MSFT 2001-12-01   26.95
#   24    MSFT 2002-01-01   25.92
#   25    MSFT 2002-02-01   23.73
#   26    MSFT 2002-03-01   24.53
#   27    MSFT 2002-04-01   21.26
#   28    MSFT 2002-05-01   20.71
#   29    MSFT 2002-06-01   22.25
#   ..     ...        ...     ...
#   530   AAPL 2007-10-01  189.95
#   531   AAPL 2007-11-01  182.22
#   532   AAPL 2007-12-01  198.08
#   533   AAPL 2008-01-01  135.36
#   534   AAPL 2008-02-01  125.02
#   535   AAPL 2008-03-01  143.50
#   536   AAPL 2008-04-01  173.95
#   537   AAPL 2008-05-01  188.75
#   538   AAPL 2008-06-01  167.44
#   539   AAPL 2008-07-01  158.95
#   540   AAPL 2008-08-01  169.53
#   541   AAPL 2008-09-01  113.66
#   542   AAPL 2008-10-01  107.59
#   543   AAPL 2008-11-01   92.67
#   544   AAPL 2008-12-01   85.35
#   545   AAPL 2009-01-01   90.13
#   546   AAPL 2009-02-01   89.31
#   547   AAPL 2009-03-01  105.12
#   548   AAPL 2009-04-01  125.83
#   549   AAPL 2009-05-01  135.81
#   550   AAPL 2009-06-01  142.43
#   551   AAPL 2009-07-01  163.39
#   552   AAPL 2009-08-01  168.21
#   553   AAPL 2009-09-01  185.35
#   554   AAPL 2009-10-01  188.50
#   555   AAPL 2009-11-01  199.91
#   556   AAPL 2009-12-01  210.73
#   557   AAPL 2010-01-01  192.06
#   558   AAPL 2010-02-01  204.62
#   559   AAPL 2010-03-01  223.02
#
#   [560 rows x 3 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'symbol:N'
#     }),
#     x: X({
#       shorthand: 'date:T'
#     }),
#     y: Y({
#       shorthand: 'price:Q'
#     })
#   }),
#   mark: MarkDef({
#     point: True,
#     type: 'line'
#   })
# })

# %%
source.head()
# Out:
#   symbol       date  price
# 0   MSFT 2000-01-01  39.81
# 1   MSFT 2000-02-01  36.35
# 2   MSFT 2000-03-01  43.22
# 3   MSFT 2000-04-01  28.37
# 4   MSFT 2000-05-01  25.45

# %%
from vega_datasets import data

df = data.seattle_weather()
df.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
import altair as alt

alt.Chart(df).mark_tick().encode(
    x='precipitation',
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'precipitation'
#     })
#   }),
#   mark: 'tick'
# })

# %%
alt.Chart(df).mark_bar().encode(
    alt.X('precipitation', bin=True),
    y='count()'
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       bin: True,
#       shorthand: 'precipitation'
#     }),
#     y: Y({
#       shorthand: 'count()'
#     })
#   }),
#   mark: 'bar'
# })

# %%
alt.Chart(df).mark_line().encode(
    x='month(date):T',
    y='average(precipitation)'
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'month(date):T'
#     }),
#     y: Y({
#       shorthand: 'average(precipitation)'
#     })
#   }),
#   mark: 'line'
# })

# %%
alt.Chart(df).mark_line().encode(
    x='yearmonth(date):T',
    y='max(temp_max)',
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'yearmonth(date):T'
#     }),
#     y: Y({
#       shorthand: 'max(temp_max)'
#     })
#   }),
#   mark: 'line'
# })

# %%
alt.Chart(df).mark_line().encode(
    x='year(date):T',
    y='mean(temp_max)',
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'year(date):T'
#     }),
#     y: Y({
#       shorthand: 'mean(temp_max)'
#     })
#   }),
#   mark: 'line'
# })

# %%
alt.Chart(df).mark_bar().encode(
    x='mean(temp_max)',
    y='year(date):O'
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'mean(temp_max)'
#     }),
#     y: Y({
#       shorthand: 'year(date):O'
#     })
#   }),
#   mark: 'bar'
# })

# %%
alt.Chart(df).mark_bar().encode(
    x='mean(temp_range):Q',
    y='year(date):O'
).transform_calculate(
    temp_range="datum.temp_max - datum.temp_min"
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     x: X({
#       shorthand: 'mean(temp_range):Q'
#     }),
#     y: Y({
#       shorthand: 'year(date):O'
#     })
#   }),
#   mark: 'bar',
#   transform: [CalculateTransform({
#     as: 'temp_range',
#     calculate: 'datum.temp_max - datum.temp_min'
#   })]
# })

# %%
alt.Chart(df).mark_bar().encode(
    x='month(date):N',
    y='count()',
    color='weather',
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'weather'
#     }),
#     x: X({
#       shorthand: 'month(date):N'
#     }),
#     y: Y({
#       shorthand: 'count()'
#     })
#   }),
#   mark: 'bar'
# })

# %%
scale = alt.Scale(domain=['sun', 'fog', 'drizzle', 'rain', 'snow'],
                  range=['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd'])

# %%
alt.Chart(df).mark_bar().encode(
    x=alt.X('month(date):N', axis=alt.Axis(title='Month of the year')),
    y='count()',
    color=alt.Color('weather', legend=alt.Legend(title='Weather type'), scale=scale),
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       legend: Legend({
#         title: 'Weather type'
#       }),
#       scale: Scale({
#         domain: ['sun', 'fog', 'drizzle', 'rain', 'snow'],
#         range: ['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd']
#       }),
#       shorthand: 'weather'
#     }),
#     x: X({
#       axis: Axis({
#         title: 'Month of the year'
#       }),
#       shorthand: 'month(date):N'
#     }),
#     y: Y({
#       shorthand: 'count()'
#     })
#   }),
#   mark: 'bar'
# })

# %%
alt.Chart(df).mark_point().encode(
    alt.X('temp_max', axis=alt.Axis(title='Maximum Daily Temperature (C)')),
    alt.Y('temp_range:Q', axis=alt.Axis(title='Daily Temperature Range (C)')),
    alt.Color('weather', scale=scale),
    alt.Size('precipitation', scale=alt.Scale(range=[1, 200]))
).transform_calculate(
    "temp_range", "datum.temp_max - datum.temp_min"
).properties(
    width=600,
    height=400
).interactive()
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       scale: Scale({
#         domain: ['sun', 'fog', 'drizzle', 'rain', 'snow'],
#         range: ['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd']
#       }),
#       shorthand: 'weather'
#     }),
#     size: Size({
#       scale: Scale({
#         range: [1, 200]
#       }),
#       shorthand: 'precipitation'
#     }),
#     x: X({
#       axis: Axis({
#         title: 'Maximum Daily Temperature (C)'
#       }),
#       shorthand: 'temp_max'
#     }),
#     y: Y({
#       axis: Axis({
#         title: 'Daily Temperature Range (C)'
#       }),
#       shorthand: 'temp_range:Q'
#     })
#   }),
#   height: 400,
#   mark: 'point',
#   selection: SelectionMapping({
#     selector001: SelectionDef({
#       bind: 'scales',
#       encodings: ['x', 'y'],
#       type: 'interval'
#     })
#   }),
#   transform: [CalculateTransform({
#     as: 'temp_range',
#     calculate: 'datum.temp_max - datum.temp_min'
#   })],
#   width: 600
# })

# %%
alt.Chart(df).mark_bar().encode(
    x='count()',
    y='weather:N',
    color=alt.Color('weather:N', scale=scale),
)
# Out:
# Chart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       scale: Scale({
#         domain: ['sun', 'fog', 'drizzle', 'rain', 'snow'],
#         range: ['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd']
#       }),
#       shorthand: 'weather:N'
#     }),
#     x: X({
#       shorthand: 'count()'
#     }),
#     y: Y({
#       shorthand: 'weather:N'
#     })
#   }),
#   mark: 'bar'
# })

# %%
brush = alt.selection(type='interval')

points = alt.Chart().mark_point().encode(
    alt.X('temp_max:Q', axis=alt.Axis(title='Maximum Daily Temperature (C)')),
    alt.Y('temp_range:Q', axis=alt.Axis(title='Daily Temperature Range (C)')),
    color=alt.condition(brush, 'weather:N', alt.value('lightgray'), scale=scale),
    size=alt.Size('precipitation:Q', scale=alt.Scale(range=[1, 200]))
).transform_calculate(
    "temp_range", "datum.temp_max - datum.temp_min"
).properties(
    width=600,
    height=400
).add_selection(
    brush
)

bars = alt.Chart().mark_bar().encode(
    x='count()',
    y='weather:N',
    color=alt.Color('weather:N', scale=scale),
).transform_calculate(
    "temp_range", "datum.temp_max - datum.temp_min"
).transform_filter(
    brush
).properties(
    width=600
)

alt.vconcat(points, bars, data=df)
# Out:
# VConcatChart({
#   data:            date  precipitation  temp_max  temp_min  wind  weather
#   0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
#   1    2012-01-02           10.9      10.6       2.8   4.5     rain
#   2    2012-01-03            0.8      11.7       7.2   2.3     rain
#   3    2012-01-04           20.3      12.2       5.6   4.7     rain
#   4    2012-01-05            1.3       8.9       2.8   6.1     rain
#   5    2012-01-06            2.5       4.4       2.2   2.2     rain
#   6    2012-01-07            0.0       7.2       2.8   2.3     rain
#   7    2012-01-08            0.0      10.0       2.8   2.0      sun
#   8    2012-01-09            4.3       9.4       5.0   3.4     rain
#   9    2012-01-10            1.0       6.1       0.6   3.4     rain
#   10   2012-01-11            0.0       6.1      -1.1   5.1      sun
#   11   2012-01-12            0.0       6.1      -1.7   1.9      sun
#   12   2012-01-13            0.0       5.0      -2.8   1.3      sun
#   13   2012-01-14            4.1       4.4       0.6   5.3     snow
#   14   2012-01-15            5.3       1.1      -3.3   3.2     snow
#   15   2012-01-16            2.5       1.7      -2.8   5.0     snow
#   16   2012-01-17            8.1       3.3       0.0   5.6     snow
#   17   2012-01-18           19.8       0.0      -2.8   5.0     snow
#   18   2012-01-19           15.2      -1.1      -2.8   1.6     snow
#   19   2012-01-20           13.5       7.2      -1.1   2.3     snow
#   20   2012-01-21            3.0       8.3       3.3   8.2     rain
#   21   2012-01-22            6.1       6.7       2.2   4.8     rain
#   22   2012-01-23            0.0       8.3       1.1   3.6     rain
#   23   2012-01-24            8.6      10.0       2.2   5.1     rain
#   24   2012-01-25            8.1       8.9       4.4   5.4     rain
#   25   2012-01-26            4.8       8.9       1.1   4.8     rain
#   26   2012-01-27            0.0       6.7      -2.2   1.4  drizzle
#   27   2012-01-28            0.0       6.7       0.6   2.2     rain
#   28   2012-01-29           27.7       9.4       3.9   4.5     rain
#   29   2012-01-30            3.6       8.3       6.1   5.1     rain
#   ...         ...            ...       ...       ...   ...      ...
#   1431 2015-12-02            2.5      10.6       4.4   5.0      fog
#   1432 2015-12-03           12.7      15.6       7.8   5.9      fog
#   1433 2015-12-04            2.0      10.6       6.1   4.7      fog
#   1434 2015-12-05           15.7      10.0       6.1   4.0      fog
#   1435 2015-12-06           11.2      12.8       7.2   5.9      fog
#   1436 2015-12-07           27.4      11.1       8.3   3.4      fog
#   1437 2015-12-08           54.1      15.6      10.0   6.2      fog
#   1438 2015-12-09           13.5      12.2       7.8   6.3      fog
#   1439 2015-12-10            9.4      11.7       6.1   7.5      fog
#   1440 2015-12-11            0.3       9.4       4.4   2.8      sun
#   1441 2015-12-12           16.0       8.9       5.6   5.6      fog
#   1442 2015-12-13            1.3       7.8       6.1   6.1      sun
#   1443 2015-12-14            0.0       7.8       1.7   1.7      sun
#   1444 2015-12-15            1.5       6.7       1.1   2.9      fog
#   1445 2015-12-16            3.6       6.1       2.8   2.3      fog
#   1446 2015-12-17           21.8       6.7       3.9   6.0      fog
#   1447 2015-12-18           18.5       8.9       4.4   5.1      fog
#   1448 2015-12-19            0.0       8.3       2.8   4.1      fog
#   1449 2015-12-20            4.3       7.8       4.4   6.7      fog
#   1450 2015-12-21           27.4       5.6       2.8   4.3      fog
#   1451 2015-12-22            4.6       7.8       2.8   5.0      fog
#   1452 2015-12-23            6.1       5.0       2.8   7.6      fog
#   1453 2015-12-24            2.5       5.6       2.2   4.3      fog
#   1454 2015-12-25            5.8       5.0       2.2   1.5      fog
#   1455 2015-12-26            0.0       4.4       0.0   2.5      sun
#   1456 2015-12-27            8.6       4.4       1.7   2.9      fog
#   1457 2015-12-28            1.5       5.0       1.7   1.3      fog
#   1458 2015-12-29            0.0       7.2       0.6   2.6      fog
#   1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
#   1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
#   [1461 rows x 6 columns],
#   vconcat: [Chart({
#     encoding: EncodingWithFacet({
#       color: ColorValue({
#         condition: Color({
#           scale: Scale({
#             domain: ['sun', 'fog', 'drizzle', 'rain', 'snow'],
#             range: ['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd']
#           }),
#           selection: 'selector002',
#           shorthand: 'weather:N'
#         }),
#         value: 'lightgray'
#       }),
#       size: Size({
#         scale: Scale({
#           range: [1, 200]
#         }),
#         shorthand: 'precipitation:Q'
#       }),
#       x: X({
#         axis: Axis({
#           title: 'Maximum Daily Temperature (C)'
#         }),
#         shorthand: 'temp_max:Q'
#       }),
#       y: Y({
#         axis: Axis({
#           title: 'Daily Temperature Range (C)'
#         }),
#         shorthand: 'temp_range:Q'
#       })
#     }),
#     height: 400,
#     mark: 'point',
#     selection: SelectionMapping({
#       selector002: SelectionDef({
#         type: 'interval'
#       })
#     }),
#     transform: [CalculateTransform({
#       as: 'temp_range',
#       calculate: 'datum.temp_max - datum.temp_min'
#     })],
#     width: 600
#   }), Chart({
#     encoding: EncodingWithFacet({
#       color: Color({
#         scale: Scale({
#           domain: ['sun', 'fog', 'drizzle', 'rain', 'snow'],
#           range: ['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd']
#         }),
#         shorthand: 'weather:N'
#       }),
#       x: X({
#         shorthand: 'count()'
#       }),
#       y: Y({
#         shorthand: 'weather:N'
#       })
#     }),
#     mark: 'bar',
#     transform: [CalculateTransform({
#       as: 'temp_range',
#       calculate: 'datum.temp_max - datum.temp_min'
#     }), FilterTransform({
#       filter: {'selection': 'selector002'}
#     })],
#     width: 600
#   })]
# })
